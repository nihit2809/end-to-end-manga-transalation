# %%
# %cd open-mantra-dataset
# Out:
# D:\manga_translation\open-mantra-dataset

# %%
import json
import os
from shutil import copyfile

def create_yolo_annotation(book_title, page_index, image_path, annotations, image_width, image_height):
    yolo_annotations = []
    for annotation in annotations:
        x, y, w, h = annotation['x'], annotation['y'], annotation['w'], annotation['h']
        # Normalize coordinates
        x_center = (x + w / 2) / image_width
        y_center = (y + h / 2) / image_height
        w_normalized = w / image_width
        h_normalized = h / image_height
        yolo_annotations.append(f"0 {x_center} {y_center} {w_normalized} {h_normalized}")

    return yolo_annotations

def process_books(annotation_data, output_folder):
    for book in annotation_data:
        book_title = book['book_title']
        pages = book['pages']

        for page in pages:
            page_index = page['page_index']
            image_paths = page['image_paths']
            text_annotations = page['text']

            for lang, image_path in image_paths.items():
                # Get image size
                image = Image.open(image_path)
                image_width, image_height = image.size

                # Create YOLO annotation file
                yolo_annotations = create_yolo_annotation(book_title, page_index, image_path, text_annotations, image_width, image_height)

                # Save YOLO annotations to a file
                label_file_path = os.path.join(output_folder, f"{book_title}-{page_index:03d}.txt")
                with open(label_file_path, 'w') as label_file:
                    label_file.write('\n'.join(yolo_annotations))

                # Copy image to images folder
                image_file_path = os.path.join(output_folder, f"{book_title}-{page_index:03d}.jpg")
                copyfile(image_path, image_file_path)

if __name__ == "__main__":
    from PIL import Image

    # Load the annotation data from the JSON file
    with open('annotation.json', 'r', encoding='utf-8') as file:
        annotation_data = json.load(file)

    # Specify the output folder
    output_folder = 'data'

    # Process books and create YOLO annotations
    process_books(annotation_data, output_folder)

# %%
import os
import json
from PIL import Image

# Define paths
annotation_file_path = "annotation.json"
output_folder = "data-2"

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read annotation data from the JSON file
with open(annotation_file_path, 'r', encoding='utf-8') as f:
    annotation_data = json.load(f)

# Iterate through the pages and annotations
for page in annotation_data[0]["pages"]:
    page_index = page["page_index"]
    image_path = page["image_paths"]["ja"]
    
    for index, annotation in enumerate(page["text"]):
        x, y, w, h = annotation["x"], annotation["y"], annotation["w"], annotation["h"]
        text_ja = annotation["text_ja"]
        
        # Open the image and crop the bounding box
        image = Image.open(image_path)
        cropped_image = image.crop((x, y, x + w, y + h))
        
        # Save the cropped image
        output_path = os.path.join(output_folder, f"book1-{page_index:03d}-{index + 1:03d}.jpg")
        cropped_image.save(output_path)
        
        # Write the path and Japanese text to the text file
        with open("text_file.txt", 'a', encoding='utf-8') as text_file:
            text_file.write(f"{output_path}\t{text_ja}\n")

# %%
annotation_data
# Out:
# [{'book_title': 'tojime_no_siora',
#   'pages': [{'page_index': 1,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/000.jpg'},
#     'frame': [{'x': 9, 'y': 84, 'w': 733, 'h': 1080}],
#     'text': [{'x': 82,
#       'y': 952,
#       'w': 668,
#       'h': 107,
#       'text_ja': '綴じ眼のシオラ',
#       'text_en': 'bound eye siora',
#       'text_zh': '縫眼的希奧拉'},
#      {'x': 515,
#       'y': 1057,
#       'w': 254,
#       'h': 85,
#       'text_ja': '朽鷹みつき',
#       'text_en': 'Mitsuki Kuchitaka',
#       'text_zh': '朽鷹美月'}]},
#    {'page_index': 2,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/001.jpg'},
#     'frame': [{'x': 61, 'y': 0, 'w': 768, 'h': 220},
#      {'x': 179, 'y': 242, 'w': 597, 'h': 198},
#      {'x': 334, 'y': 460, 'w': 495, 'h': 709},
#      {'x': 72, 'y': 470, 'w': 240, 'h': 615}],
#     'text': [{'x': 172,
#       'y': 194,
#       'w': 126,
#       'h': 229,
#       'text_ja': 'だからっ',
#       'text_en': "I'm telling you!!",
#       'text_zh': '所以...'},
#      {'x': 692,
#       'y': 519,
#       'w': 98,
#       'h': 184,
#       'text_ja': '知らないって言ってるだろっ',
#       'text_en': "I don't know what you're talking about!",
#       'text_zh': '我不知道你在說什麼'},
#      {'x': 363,
#       'y': 754,
#       'w': 91,
#       'h': 178,
#       'text_ja': 'そんな借金なんて!',
#       'text_en': "i don't owe you!",
#       'text_zh': '我不欠你錢！'},
#      {'x': 233,
#       'y': 483,
#       'w': 78,
#       'h': 153,
#       'text_ja': 'そうは言ってもなぁ',
#       'text_en': "well, I'm sorry...",
#       'text_zh': '話雖如此'},
#      {'x': 97,
#       'y': 855,
#       'w': 106,
#       'h': 198,
#       'text_ja': 'レーネ...',
#       'text_en': 'lene...',
#       'text_zh': '蕾娜...'}]},
#    {'page_index': 3,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/002.jpg'},
#     'frame': [{'x': 455, 'y': 1, 'w': 299, 'h': 413},
#      {'x': 212, 'y': 0, 'w': 231, 'h': 412},
#      {'x': 0, 'y': 0, 'w': 197, 'h': 412},
#      {'x': 433, 'y': 444, 'w': 322, 'h': 143},
#      {'x': 433, 'y': 614, 'w': 318, 'h': 166},
#      {'x': 67, 'y': 447, 'w': 359, 'h': 334},
#      {'x': 488, 'y': 813, 'w': 266, 'h': 352},
#      {'x': 0, 'y': 810, 'w': 471, 'h': 359}],
#     'text': [{'x': 662,
#       'y': 66,
#       'w': 82,
#       'h': 118,
#       'text_ja': 'こっちにゃ借用書があんだよ',
#       'text_en': "we've got proof here...",
#       'text_zh': '這裡有借條'},
#      {'x': 460,
#       'y': 210,
#       'w': 107,
#       'h': 202,
#       'text_ja': 'トルティヤーノに借りた金はちゃんと返して貰わねぇと',
#       'text_en': 'You know we need you to pay us back...',
#       'text_zh': '你必須還錢'},
#      {'x': 233,
#       'y': 239,
#       'w': 72,
#       'h': 149,
#       'text_ja': '知るもんかっ',
#       'text_en': 'how should I know!?',
#       'text_zh': '我才不管'},
#      {'x': 96,
#       'y': 43,
#       'w': 90,
#       'h': 160,
#       'text_ja': '父親がカジノで作った借金なんて...',
#       'text_en': "how should I know about my father's debt in casinos...",
#       'text_zh': '父親欠賭場的錢我怎麼會知道'},
#      {'x': 464,
#       'y': 464,
#       'w': 56,
#       'h': 90,
#       'text_ja': 'あのぉ',
#       'text_en': 'excuse me...',
#       'text_zh': '請問'},
#      {'x': 627,
#       'y': 617,
#       'w': 120,
#       'h': 162,
#       'text_ja': 'もしやトルティヤーノ一家の方でしょうか',
#       'text_en': 'are you a member of the Tortillano family?',
#       'text_zh': '你是托蒂亞家族的嗎'},
#      {'x': 450,
#       'y': 642,
#       'w': 48,
#       'h': 79,
#       'text_ja': 'あ?',
#       'text_en': 'huh?',
#       'text_zh': '啊？'},
#      {'x': 332,
#       'y': 456,
#       'w': 75,
#       'h': 158,
#       'text_ja': '取り込み中だ出直しやがれ!',
#       'text_en': "we're having a conversation here! Get lost!",
#       'text_zh': '我們這邊出了點狀況'},
#      {'x': 41,
#       'y': 462,
#       'w': 59,
#       'h': 109,
#       'text_ja': 'え、あっあのっ...',
#       'text_en': 'uh, um...',
#       'text_zh': '啊，這，這個...'},
#      {'x': 657,
#       'y': 835,
#       'w': 86,
#       'h': 160,
#       'text_ja': '待ってくださーー',
#       'text_en': 'Please...! Wait...',
#       'text_zh': '請等一下'},
#      {'x': 402,
#       'y': 816,
#       'w': 72,
#       'h': 112,
#       'text_ja': 'あっ',
#       'text_en': 'ah!',
#       'text_zh': '啊！'},
#      {'x': 31,
#       'y': 840,
#       'w': 52,
#       'h': 79,
#       'text_ja': 'がっ',
#       'text_en': 'guh!',
#       'text_zh': '噶'}]},
#    {'page_index': 4,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/003.jpg'},
#     'frame': [{'x': 413, 'y': 1, 'w': 413, 'h': 281},
#      {'x': 78, 'y': 0, 'w': 320, 'h': 285},
#      {'x': 90, 'y': 295, 'w': 690, 'h': 547},
#      {'x': 117, 'y': 568, 'w': 117, 'h': 246},
#      {'x': 615, 'y': 840, 'w': 214, 'h': 328},
#      {'x': 311, 'y': 839, 'w': 296, 'h': 330},
#      {'x': 79, 'y': 844, 'w': 221, 'h': 325}],
#     'text': [{'x': 714,
#       'y': 52,
#       'w': 74,
#       'h': 163,
#       'text_ja': 'てってめぇ...!',
#       'text_en': 'hey, you...',
#       'text_zh': '臭小子！'},
#      {'x': 411,
#       'y': 31,
#       'w': 146,
#       'h': 210,
#       'text_ja': 'すいません...っ目の見えない「閉じ眼」なものでつい転んでじゃって',
#       'text_en': 'i\'m sorry, i can\'t see, I am a "closed-eyes"...',
#       'text_zh': '不好意思... 眼睛蒙住看不到'},
#      {'x': 279,
#       'y': 41,
#       'w': 121,
#       'h': 155,
#       'text_ja': '閉じ眼がマフィアに何の用だコラァ!!',
#       'text_en': 'so what does a closed-eyes want from the likes of us!',
#       'text_zh': '餵，蒙眼睛的傢伙，找我們想幹什麼？'},
#      {'x': 101,
#       'y': 161,
#       'w': 57,
#       'h': 104,
#       'text_ja': 'え、ええと...',
#       'text_en': 'uh...',
#       'text_zh': '這， 這個...'},
#      {'x': 603,
#       'y': 341,
#       'w': 125,
#       'h': 241,
#       'text_ja': '流しのガンマンをしているシオラと申します',
#       'text_en': "I'm siora, a gunman",
#       'text_zh': '我是行雲流水的槍手，希奧拉'},
#      {'x': 138,
#       'y': 314,
#       'w': 169,
#       'h': 165,
#       'text_ja': 'ここら一帯を仕切るトルティヤー一家の名が聞こえたので',
#       'text_en': 'I heard that you Tortillanos are in charge around here',
#       'text_zh': '因為聽說了在這一帶混的托蒂亞家族'},
#      {'x': 215,
#       'y': 501,
#       'w': 91,
#       'h': 157,
#       'text_ja': '用心棒として雇っていただけないかと...',
#       'text_en': 'so i was wondering if you could hire me as a bodyguard...',
#       'text_zh': '所以我在想你們要不要雇我...'},
#      {'x': 615,
#       'y': 868,
#       'w': 121,
#       'h': 137,
#       'text_ja': '目の見えない閉じ眼が...',
#       'text_en': 'so a closed-eyes is...',
#       'text_zh': '一個蒙眼的…'},
#      {'x': 321,
#       'y': 1006,
#       'w': 65,
#       'h': 119,
#       'text_ja': 'ガンマンだって...?',
#       'text_en': 'a gunman...?',
#       'text_zh': '槍手？'},
#      {'x': 89,
#       'y': 988,
#       'w': 60,
#       'h': 80,
#       'text_ja': 'おう...',
#       'text_en': 'well...',
#       'text_zh': '噢...'}]},
#    {'page_index': 5,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/004.jpg'},
#     'frame': [{'x': 10, 'y': 4, 'w': 750, 'h': 419},
#      {'x': 323, 'y': 459, 'w': 432, 'h': 233},
#      {'x': 75, 'y': 457, 'w': 233, 'h': 232},
#      {'x': 450, 'y': 722, 'w': 303, 'h': 447},
#      {'x': 284, 'y': 723, 'w': 155, 'h': 372},
#      {'x': 1, 'y': 719, 'w': 273, 'h': 449}],
#     'text': [{'x': 617,
#       'y': 50,
#       'w': 121,
#       'h': 218,
#       'text_ja': 'マフィア舐めんのも大概にしやがれ',
#       'text_en': "Don't mess with us.",
#       'text_zh': '大概是小看了黑社會'},
#      {'x': 207,
#       'y': 128,
#       'w': 46,
#       'h': 88,
#       'text_ja': 'あっ',
#       'text_en': 'ah..',
#       'text_zh': '啊！'},
#      {'x': 37,
#       'y': 72,
#       'w': 121,
#       'h': 154,
#       'text_ja': '閉じ眼が用心棒だ?',
#       'text_en': 'closed-eyes for a bodyguard?',
#       'text_zh': '封著眼睛的那個傢伙是保鏢？'},
#      {'x': 644,
#       'y': 464,
#       'w': 110,
#       'h': 158,
#       'text_ja': '腰の銃でイかれた脳みそぶちまけてみるか?',
#       'text_en': 'do you want me to shoot your brains out?!',
#       'text_zh': '嚐嚐用腰間的槍讓腦漿開花如何？'},
#      {'x': 586,
#       'y': 544,
#       'w': 48,
#       'h': 60,
#       'text_ja': 'あ?',
#       'text_en': 'huh?',
#       'text_zh': '啊？'},
#      {'x': 491,
#       'y': 516,
#       'w': 42,
#       'h': 70,
#       'text_ja': 'あ、あの...',
#       'text_en': 'er...',
#       'text_zh': '那，那個...'},
#      {'x': 331,
#       'y': 471,
#       'w': 90,
#       'h': 157,
#       'text_ja': 'ちょっとやめてよ!こんなとこで!',
#       'text_en': 'hey, just please stop!',
#       'text_zh': '等等，別這樣，這個樣子！'},
#      {'x': 263,
#       'y': 467,
#       'w': 40,
#       'h': 84,
#       'text_ja': '...',
#       'text_en': '...',
#       'text_zh': '...'},
#      {'x': 87,
#       'y': 587,
#       'w': 48,
#       'h': 62,
#       'text_ja': 'ん?',
#       'text_en': 'huh?',
#       'text_zh': '嗯？'},
#      {'x': 678,
#       'y': 731,
#       'w': 71,
#       'h': 128,
#       'text_ja': 'お前もしかして',
#       'text_en': 'are you...',
#       'text_zh': '難道你是...'},
#      {'x': 491,
#       'y': 763,
#       'w': 58,
#       'h': 107,
#       'text_ja': '女か?',
#       'text_en': 'a girl?',
#       'text_zh': '女的嗎？'},
#      {'x': 477,
#       'y': 962,
#       'w': 63,
#       'h': 153,
#       'text_ja': 'えっはい...そうですけど...',
#       'text_en': 'yes, but so...?',
#       'text_zh': '啊，是的... 但是...'},
#      {'x': 292,
#       'y': 975,
#       'w': 60,
#       'h': 84,
#       'text_ja': 'ほぉ',
#       'text_en': 'oh well...',
#       'text_zh': '吼'},
#      {'x': 207,
#       'y': 731,
#       'w': 58,
#       'h': 115,
#       'text_ja': '面見せてみろ',
#       'text_en': "let's take a look at your face.",
#       'text_zh': '給我看看臉'},
#      {'x': 136,
#       'y': 774,
#       'w': 48,
#       'h': 58,
#       'text_ja': 'えっ',
#       'text_en': 'hey!',
#       'text_zh': '什麼？'},
#      {'x': 28,
#       'y': 737,
#       'w': 97,
#       'h': 155,
#       'text_ja': '閉じ眼でも器量が良けりゃ貿い手は...',
#       'text_en': "If you have good qualities, your eyes wouldn't be a concern",
#       'text_zh': '就算封著眼睛，如果姿色夠好，那也可以...'},
#      {'x': 25,
#       'y': 960,
#       'w': 79,
#       'h': 146,
#       'text_ja': 'やっちょっと...!',
#       'text_en': 'hey, wait!',
#       'text_zh': '餵！等一下...'}]},
#    {'page_index': 6,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/005.jpg'},
#     'frame': [{'x': 290, 'y': 0, 'w': 539, 'h': 320},
#      {'x': 76, 'y': 0, 'w': 199, 'h': 322},
#      {'x': 301, 'y': 311, 'w': 525, 'h': 858},
#      {'x': 76, 'y': 348, 'w': 224, 'h': 237},
#      {'x': 71, 'y': 580, 'w': 223, 'h': 515}],
#     'text': [{'x': 340,
#       'y': 60,
#       'w': 78,
#       'h': 172,
#       'text_ja': 'ーー!?',
#       'text_en': '?!',
#       'text_zh': '！ ？'},
#      {'x': 215,
#       'y': 63,
#       'w': 55,
#       'h': 113,
#       'text_ja': 'なんだこりゃあ...',
#       'text_en': 'what the...',
#       'text_zh': '這是什麼？'},
#      {'x': 94,
#       'y': 75,
#       'w': 53,
#       'h': 95,
#       'text_ja': 'てめぇ...',
#       'text_en': 'you...',
#       'text_zh': '臭小子...'},
#      {'x': 100,
#       'y': 220,
#       'w': 28,
#       'h': 48,
#       'text_ja': '?',
#       'text_en': '?',
#       'text_zh': '？'},
#      {'x': 680,
#       'y': 358,
#       'w': 116,
#       'h': 236,
#       'text_ja': 'なんてもん見せやがるっ!!',
#       'text_en': 'what is this!!',
#       'text_zh': '這是什麼！'},
#      {'x': 227,
#       'y': 359,
#       'w': 68,
#       'h': 98,
#       'text_ja': 'ひっひどい!',
#       'text_en': 'how dare you!',
#       'text_zh': '好過分！'},
#      {'x': 232,
#       'y': 599,
#       'w': 67,
#       'h': 139,
#       'text_ja': '大丈夫かいあんたっ',
#       'text_en': 'are you all right?!',
#       'text_zh': '你沒事吧？'},
#      {'x': 94,
#       'y': 926,
#       'w': 71,
#       'h': 128,
#       'text_ja': '今日は帰ってやる',
#       'text_en': "i'll leave for today.",
#       'text_zh': '今天我先回去了'}]},
#    {'page_index': 7,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/006.jpg'},
#     'frame': [{'x': 68, 'y': 0, 'w': 689, 'h': 280},
#      {'x': 43, 'y': 341, 'w': 713, 'h': 183},
#      {'x': 68, 'y': 551, 'w': 684, 'h': 228},
#      {'x': 489, 'y': 804, 'w': 266, 'h': 362},
#      {'x': 269, 'y': 804, 'w': 208, 'h': 360},
#      {'x': 0, 'y': 807, 'w': 257, 'h': 362}],
#     'text': [{'x': 618,
#       'y': 39,
#       'w': 95,
#       'h': 180,
#       'text_ja': 'だがいつまでもこうしてられると思うなよ',
#       'text_en': "but don't think you can stay like this forever.",
#       'text_zh': '但不要以為你能一直待在這裡'},
#      {'x': 135,
#       'y': 67,
#       'w': 64,
#       'h': 130,
#       'text_ja': 'レーネ',
#       'text_en': 'lene',
#       'text_zh': '蕾娜'},
#      {'x': 693,
#       'y': 346,
#       'w': 59,
#       'h': 90,
#       'text_ja': '馬鹿か',
#       'text_en': 'are you nuts?',
#       'text_zh': '笨蛋嗎'},
#      {'x': 644,
#       'y': 393,
#       'w': 53,
#       'h': 109,
#       'text_ja': 'アンタは',
#       'text_en': 'you...',
#       'text_zh': '你...'},
#      {'x': 90,
#       'y': 350,
#       'w': 157,
#       'h': 166,
#       'text_ja': '撃ち合いで成り上がったトルティヤー一家に銃の腕を買えだ?',
#       'text_en': 'The Tortillanos are notorious for their gun fights! did you really think that they would hire you? ',
#       'text_zh': '托蒂亞家族臭名昭著，你真的認為他們會僱傭你嗎'},
#      {'x': 642,
#       'y': 559,
#       'w': 92,
#       'h': 213,
#       'text_ja': '挙句の果てにビル・トルティヤーにケンカを売るなんて',
#       'text_en': 'and  picking a fight with "the" bill tortillano?',
#       'text_zh': '挑起和比爾·托蒂亞的爭鬥...'},
#      {'x': 92,
#       'y': 559,
#       'w': 136,
#       'h': 201,
#       'text_ja': '奴はトルティヤー兄弟の片割れ、この街で一番の荒くれだよ',
#       'text_en': "he's one half of the Tortillano brothers, and the most violent in town.",
#       'text_zh': '那個傢伙是托蒂亞兄弟的一員，是這條街最暴力的人。'},
#      {'x': 698,
#       'y': 810,
#       'w': 44,
#       'h': 95,
#       'text_ja': 'なるほど',
#       'text_en': 'i see.',
#       'text_zh': '原來如此'},
#      {'x': 499,
#       'y': 822,
#       'w': 144,
#       'h': 156,
#       'text_ja': 'さっきの7フィート程の巨漢が、マフィア兄弟の弟の方...',
#       'text_en': 'so that 7-feet-tall guy is the younger one of the mafia brothers.',
#       'text_zh': '剛才的7英尺大漢是托蒂亞兄弟中最小的'},
#      {'x': 417,
#       'y': 811,
#       'w': 58,
#       'h': 91,
#       'text_ja': 'そうさ!',
#       'text_en': "that's right!",
#       'text_zh': '就是這樣！'},
#      {'x': 273,
#       'y': 942,
#       'w': 79,
#       'h': 174,
#       'text_ja': '悪いこた言わないからさっさと街から...',
#       'text_en': "so you'd better get out of this town as soon as possible.",
#       'text_zh': '你最好趕緊走， 越快越好'},
#      {'x': 145,
#       'y': 808,
#       'w': 110,
#       'h': 139,
#       'text_ja': '...ん?確かにビルの背丈はそのくらいだが',
#       'text_en': "...wait a second. Bill's height is actually around 7, but",
#       'text_zh': '...嗯？比爾確實差不多那麼高'},
#      {'x': 35,
#       'y': 827,
#       'w': 112,
#       'h': 175,
#       'text_ja': '目が見えないのになんで正確にわかるんだ...?',
#       'text_en': "How do you know when you can't see anything...?",
#       'text_zh': '你不是看不到嗎...？'}]},
#    {'page_index': 8,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/007.jpg'},
#     'frame': [{'x': 388, 'y': 0, 'w': 441, 'h': 511},
#      {'x': 75, 'y': 0, 'w': 297, 'h': 298},
#      {'x': 74, 'y': 333, 'w': 295, 'h': 180},
#      {'x': 57, 'y': 542, 'w': 708, 'h': 182},
#      {'x': 602, 'y': 755, 'w': 227, 'h': 414},
#      {'x': 332, 'y': 752, 'w': 256, 'h': 417},
#      {'x': 74, 'y': 755, 'w': 245, 'h': 413}],
#     'text': [{'x': 694,
#       'y': 71,
#       'w': 99,
#       'h': 183,
#       'text_ja': '声がする方向と足音の重さで大体わかりますよ',
#       'text_en': 'I can tell from whereabouts of the voice and how heavy the footsteps sounded.',
#       'text_zh': '我可以從他腳步的聲音的輕重分辨'},
#      {'x': 394,
#       'y': 86,
#       'w': 115,
#       'h': 170,
#       'text_ja': 'あなたは五・七フィートの身長に比べ体重が少々重めスリーサイズは...',
#       'text_en': "you're 5 feet 7, you're slightly heavier than your height's average",
#       'text_zh': '你身高五英尺7英寸，比平均體重稍重...'},
#      {'x': 250,
#       'y': 29,
#       'w': 63,
#       'h': 64,
#       'text_ja': 'なっ',
#       'text_en': 'what?!',
#       'text_zh': '什麼？'},
#      {'x': 85,
#       'y': 30,
#       'w': 67,
#       'h': 155,
#       'text_ja': 'そこまでわかんのかよっ',
#       'text_en': 'how do you know that much!',
#       'text_zh': '你怎麼知道那麼多'},
#      {'x': 103,
#       'y': 217,
#       'w': 70,
#       'h': 79,
#       'text_ja': '冗談ですよ',
#       'text_en': "I'm just kidding.",
#       'text_zh': '我開玩笑的'},
#      {'x': 294,
#       'y': 337,
#       'w': 61,
#       'h': 108,
#       'text_ja': '...こりてねーな',
#       'text_en': "Don't say that again.",
#       'text_zh': '以後別這麼說了'},
#      {'x': 153,
#       'y': 346,
#       'w': 48,
#       'h': 85,
#       'text_ja': 'ははっ',
#       'text_en': 'ha, ha.',
#       'text_zh': '哈哈'},
#      {'x': 91,
#       'y': 406,
#       'w': 74,
#       'h': 100,
#       'text_ja': 'では私はそろそろ',
#       'text_en': 'well, i should get going.',
#       'text_zh': '我該走了'},
#      {'x': 678,
#       'y': 548,
#       'w': 83,
#       'h': 143,
#       'text_ja': '今晩の宿を探さないと...',
#       'text_en': 'I need to find a place to stay tonight.',
#       'text_zh': '我得找到今晚的住宿'},
#      {'x': 337,
#       'y': 580,
#       'w': 55,
#       'h': 76,
#       'text_ja': 'いたっ',
#       'text_en': 'ouch.',
#       'text_zh': '在這兒'},
#      {'x': 110,
#       'y': 581,
#       'w': 45,
#       'h': 100,
#       'text_ja': '...',
#       'text_en': '...',
#       'text_zh': '...'},
#      {'x': 729,
#       'y': 780,
#       'w': 89,
#       'h': 160,
#       'text_ja': 'あーもうっ',
#       'text_en': 'ugh, fine!',
#       'text_zh': '啊-好吧...'},
#      {'x': 512,
#       'y': 758,
#       'w': 66,
#       'h': 111,
#       'text_ja': '厄介払いのお礼だ',
#       'text_en': 'I guess I have a lot to thank for.',
#       'text_zh': '我們有一堆要忙的事情'},
#      {'x': 345,
#       'y': 932,
#       'w': 86,
#       'h': 165,
#       'text_ja': 'まずはその薄汚れた格好をなんとかするよ',
#       'text_en': 'first, we need to do something about your dirty clothes.',
#       'text_zh': '首先，把你那一堆髒衣服收拾乾淨'},
#      {'x': 259,
#       'y': 777,
#       'w': 53,
#       'h': 79,
#       'text_ja': '目元',
#       'text_en': 'your eyes.',
#       'text_zh': '眼睛'},
#      {'x': 89,
#       'y': 761,
#       'w': 72,
#       'h': 224,
#       'text_ja': '見られたくなかったらタオルでも巻いてな',
#       'text_en': "if you don't want me to see them, cover them with a towel.",
#       'text_zh': '如果你不想看，就用毛巾包起來'}]},
#    {'page_index': 9,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/008.jpg'},
#     'frame': [{'x': 274, 'y': 18, 'w': 548, 'h': 800},
#      {'x': 644, 'y': 74, 'w': 114, 'h': 419},
#      {'x': 0, 'y': 0, 'w': 274, 'h': 277},
#      {'x': 1, 'y': 308, 'w': 281, 'h': 189},
#      {'x': 0, 'y': 509, 'w': 272, 'h': 255},
#      {'x': 364, 'y': 793, 'w': 391, 'h': 376},
#      {'x': 2, 'y': 791, 'w': 356, 'h': 378}],
#     'text': [{'x': 325,
#       'y': 100,
#       'w': 119,
#       'h': 146,
#       'text_ja': 'あっありがとうございますっ',
#       'text_en': 'well... thank you.',
#       'text_zh': '好吧，謝謝你...'},
#      {'x': 573,
#       'y': 448,
#       'w': 69,
#       'h': 84,
#       'text_ja': '洗ってやるよ',
#       'text_en': 'just leave everything to me.',
#       'text_zh': '洗一洗'},
#      {'x': 613,
#       'y': 269,
#       'w': 115,
#       'h': 175,
#       'text_ja': '人の家のシャワーじゃ勝手がわからないだろ',
#       'text_en': "you don't know how to shower in someone else's house, do you?",
#       'text_zh': '都讓我來吧，你不知道怎麼在別人家洗澡吧'},
#      {'x': 201,
#       'y': 30,
#       'w': 43,
#       'h': 79,
#       'text_ja': '...あの',
#       'text_en': 'um...',
#       'text_zh': '那...'},
#      {'x': 17,
#       'y': 43,
#       'w': 121,
#       'h': 170,
#       'text_ja': '閉じ眼の扱いにずいぶん慣れてらっしゃるんですね',
#       'text_en': 'you seem really used to treating closed-eyes people like me ',
#       'text_zh': '你看起來很習慣照顧盲人'},
#      {'x': 208,
#       'y': 348,
#       'w': 51,
#       'h': 65,
#       'text_ja': 'ああ...',
#       'text_en': 'ah...',
#       'text_zh': '嗯...'},
#      {'x': 51,
#       'y': 553,
#       'w': 78,
#       'h': 144,
#       'text_ja': 'うちの父親も目が悪かったんだ',
#       'text_en': "my father's sights weren't good, either.",
#       'text_zh': '我父親的視力也不太好'},
#      {'x': 675,
#       'y': 834,
#       'w': 51,
#       'h': 84,
#       'text_ja': 'いや...',
#       'text_en': 'no...',
#       'text_zh': '不...'},
#      {'x': 383,
#       'y': 965,
#       'w': 99,
#       'h': 131,
#       'text_ja': '正確には悪くなっていったのさ',
#       'text_en': 'It gradually got worse, to be exact',
#       'text_zh': '確切地說，是每況愈下'},
#      {'x': 265,
#       'y': 799,
#       'w': 82,
#       'h': 146,
#       'text_ja': 'ひどい父親さ...しがない絵描きでね',
#       'text_en': "he wasn't a good father. he was just a plain old painter.",
#       'text_zh': '他不是一個好父親，只是一個平庸的老畫家'},
#      {'x': 30,
#       'y': 792,
#       'w': 115,
#       'h': 186,
#       'text_ja': '金になるからって女の裸ばかり描いてトルティヤーに卸してた',
#       'text_en': 'he kept drawing naked woman to sell them to the tortillanos.',
#       'text_zh': '為了錢，畫裸體女生賣給托蒂亞'}]},
#    {'page_index': 10,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/009.jpg'},
#     'frame': [{'x': 59, 'y': 0, 'w': 770, 'h': 296},
#      {'x': 71, 'y': 295, 'w': 693, 'h': 202},
#      {'x': 69, 'y': 525, 'w': 707, 'h': 201},
#      {'x': 287, 'y': 758, 'w': 542, 'h': 410},
#      {'x': 76, 'y': 754, 'w': 199, 'h': 343}],
#     'text': [{'x': 682,
#       'y': 54,
#       'w': 104,
#       'h': 186,
#       'text_ja': 'だけど病気でどんどん目が悪くなっていってね',
#       'text_en': 'but his eyes got worse and worse.',
#       'text_zh': '可是因為病情視力越來越差'},
#      {'x': 575,
#       'y': 105,
#       'w': 101,
#       'h': 184,
#       'text_ja': '絵描きなりにショックだったんだろう',
#       'text_en': 'he must have been in so much pain.',
#       'text_zh': '繪畫上受到了很大打擊'},
#      {'x': 180,
#       'y': 46,
#       'w': 104,
#       'h': 177,
#       'text_ja': '仕事が減って金もなくなって焼きが回ったのか',
#       'text_en': 'He had less job, less money and ',
#       'text_zh': '工作減少了，錢也沒有了，很著急吧'},
#      {'x': 91,
#       'y': 129,
#       'w': 97,
#       'h': 142,
#       'text_ja': '私をモデルにしようとする始末さ',
#       'text_en': ' he even tried to use me as the model for his paintings',
#       'text_zh': '他甚至試圖讓我做他裸體畫的模特'},
#      {'x': 632,
#       'y': 299,
#       'w': 116,
#       'h': 140,
#       'text_ja': '挙句の果てに博打で借金こさえて川にドボン',
#       'text_en': 'in the end he made debt from gambling, and he dove into the river.',
#       'text_zh': '最終因欠下賭債，跳河自殺'},
#      {'x': 126,
#       'y': 327,
#       'w': 90,
#       'h': 131,
#       'text_ja': 'ひどい父親だろ?',
#       'text_en': 'worst father ever, huh?',
#       'text_zh': '差勁的父親，對吧？'},
#      {'x': 507,
#       'y': 550,
#       'w': 49,
#       'h': 87,
#       'text_ja': '...結局',
#       'text_en': 'so...',
#       'text_zh': '所以...'},
#      {'x': 161,
#       'y': 559,
#       'w': 74,
#       'h': 136,
#       'text_ja': 'レーネさんはモデルに?',
#       'text_en': 'did you model for him?',
#       'text_zh': '你做了他的模特嗎？'},
#      {'x': 759,
#       'y': 812,
#       'w': 59,
#       'h': 75,
#       'text_ja': '...ああ',
#       'text_en': 'yeah...',
#       'text_zh': '嗯...'},
#      {'x': 707,
#       'y': 871,
#       'w': 76,
#       'h': 136,
#       'text_ja': 'しつこいもんだったからさ',
#       'text_en': 'he was so persistent.',
#       'text_zh': '因為他一直堅持'},
#      {'x': 306,
#       'y': 765,
#       'w': 115,
#       'h': 179,
#       'text_ja': '私なんか描いても大した金にならなかっただろうけど...',
#       'text_en': "I don't think I made him much money, though.",
#       'text_zh': '雖然畫我也賣不了幾個錢...'},
#      {'x': 218,
#       'y': 766,
#       'w': 60,
#       'h': 84,
#       'text_ja': 'そう...',
#       'text_en': 'well...',
#       'text_zh': '是嗎？'},
#      {'x': 140,
#       'y': 944,
#       'w': 64,
#       'h': 118,
#       'text_ja': 'それはよかった...',
#       'text_en': "I'm glad...",
#       'text_zh': '太好了...'}]},
#    {'page_index': 11,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/010.jpg'},
#     'frame': [{'x': 11, 'y': 1, 'w': 759, 'h': 618},
#      {'x': 3, 'y': 1, 'w': 248, 'h': 593},
#      {'x': 78, 'y': 3, 'w': 134, 'h': 460},
#      {'x': 65, 'y': 654, 'w': 699, 'h': 159},
#      {'x': 0, 'y': 910, 'w': 760, 'h': 259}],
#     'text': [{'x': 622,
#       'y': 77,
#       'w': 106,
#       'h': 193,
#       'text_ja': 'さぞ嬉しかったことでしょう',
#       'text_en': 'he must have been really happy',
#       'text_zh': '他應該很高興吧'},
#      {'x': 140,
#       'y': 344,
#       'w': 125,
#       'h': 216,
#       'text_ja': '目が見えなくなる前に娘さんを描くことができて',
#       'text_en': 'to be able to draw his daughter before he lost his sights completely.',
#       'text_zh': '在失明之前可以畫自己的女兒'}]},
#    {'page_index': 12,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/011.jpg'},
#     'frame': [{'x': 344, 'y': 2, 'w': 482, 'h': 267},
#      {'x': 74, 'y': 0, 'w': 264, 'h': 270},
#      {'x': 510, 'y': 298, 'w': 245, 'h': 218},
#      {'x': 76, 'y': 300, 'w': 421, 'h': 217},
#      {'x': 65, 'y': 545, 'w': 693, 'h': 162},
#      {'x': 255, 'y': 736, 'w': 574, 'h': 429},
#      {'x': 76, 'y': 730, 'w': 244, 'h': 439}],
#     'text': [{'x': 701,
#       'y': 39,
#       'w': 72,
#       'h': 108,
#       'text_ja': 'レーネさん?',
#       'text_en': 'lene?',
#       'text_zh': '蕾娜小姐？'},
#      {'x': 556,
#       'y': 41,
#       'w': 84,
#       'h': 97,
#       'text_ja': 'なっなんでもないよ',
#       'text_en': "no, it's nothing.",
#       'text_zh': '沒什麼啦'},
#      {'x': 357,
#       'y': 37,
#       'w': 66,
#       'h': 100,
#       'text_ja': '背中は終わりだ',
#       'text_en': "I'm done with you're back.",
#       'text_zh': '我擦完你的背了'},
#      {'x': 240,
#       'y': 39,
#       'w': 75,
#       'h': 131,
#       'text_ja': 'ほらこっち向きな',
#       'text_en': 'come on, turn around.',
#       'text_zh': '現在轉向這邊'},
#      {'x': 710,
#       'y': 329,
#       'w': 89,
#       'h': 112,
#       'text_ja': 'それよりアンタはどうなのさ',
#       'text_en': 'by the way, what about you?',
#       'text_zh': '對了,你呢？'},
#      {'x': 418,
#       'y': 308,
#       'w': 76,
#       'h': 141,
#       'text_ja': 'なんで銃なんか持って旅してんだい',
#       'text_en': 'why did you take your gun with you?',
#       'text_zh': '你為什麼要帶槍旅行呢？'},
#      {'x': 102,
#       'y': 327,
#       'w': 60,
#       'h': 90,
#       'text_ja': 'その眼だって...',
#       'text_en': 'and those eyes...',
#       'text_zh': '你的眼睛...'},
#      {'x': 112,
#       'y': 551,
#       'w': 120,
#       'h': 145,
#       'text_ja': '大したことじゃありませんよ',
#       'text_en': "it's no big deal.",
#       'text_zh': '沒什麼大不了的'},
#      {'x': 713,
#       'y': 790,
#       'w': 77,
#       'h': 226,
#       'text_ja': '親を殺したマフィアを撃ち殺したんです',
#       'text_en': 'I killed a mafia who killed my parents.',
#       'text_zh': '我殺了害死我父母的黑手黨'},
#      {'x': 333,
#       'y': 903,
#       'w': 105,
#       'h': 184,
#       'text_ja': 'その咎で故郷を追い出されました',
#       'text_en': "and that's how I was kicked out of my hometown.",
#       'text_zh': '所以被從家鄉趕出來了'},
#      {'x': 197,
#       'y': 743,
#       'w': 57,
#       'h': 98,
#       'text_ja': 'この眼は',
#       'text_en': 'and these eyes...',
#       'text_zh': '這個眼睛'},
#      {'x': 78,
#       'y': 951,
#       'w': 72,
#       'h': 136,
#       'text_ja': 'その時に罪の証にと...',
#       'text_en': 'are proof of sin.',
#       'text_zh': '是當時我犯下罪行的證明'}]},
#    {'page_index': 13,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/012.jpg'},
#     'frame': [{'x': 1, 'y': 0, 'w': 762, 'h': 238},
#      {'x': 0, 'y': 232, 'w': 749, 'h': 225},
#      {'x': 0, 'y': 452, 'w': 764, 'h': 404},
#      {'x': 227, 'y': 851, 'w': 394, 'h': 318},
#      {'x': 539, 'y': 854, 'w': 208, 'h': 311},
#      {'x': 1, 'y': 868, 'w': 246, 'h': 301}],
#     'text': [{'x': 622,
#       'y': 66,
#       'w': 52,
#       'h': 91,
#       'text_ja': '...',
#       'text_en': '... ',
#       'text_zh': '...'},
#      {'x': 68,
#       'y': 42,
#       'w': 98,
#       'h': 148,
#       'text_ja': '眼を潰されたっていうかい...?',
#       'text_en': "and that's how you were made blind...?",
#       'text_zh': '因為這樣，你的眼睛被弄瞎了？'},
#      {'x': 684,
#       'y': 248,
#       'w': 55,
#       'h': 92,
#       'text_ja': 'なんてひどい...',
#       'text_en': 'how terrible...',
#       'text_zh': '太過分了'},
#      {'x': 461,
#       'y': 247,
#       'w': 104,
#       'h': 183,
#       'text_ja': 'アンタは親の仇を討っただけじゃないか!',
#       'text_en': 'all you did was avenge your family!',
#       'text_zh': '你只是為了替父母報仇而已！'},
#      {'x': 322,
#       'y': 249,
#       'w': 93,
#       'h': 199,
#       'text_ja': '何もひどいことなんてありませんよレーネさん',
#       'text_en': "There's nothing terrible about this.",
#       'text_zh': '蕾娜小姐， 這件事沒什麼'},
#      {'x': 29,
#       'y': 241,
#       'w': 131,
#       'h': 158,
#       'text_ja': 'あなたの父親のかけらほども悲劇ではないんです',
#       'text_en': "it's not half as tragic as your father's story.",
#       'text_zh': '比起你父親的事，不算什麼'},
#      {'x': 630,
#       'y': 511,
#       'w': 85,
#       'h': 192,
#       'text_ja': '私は自ら望んで血を求めた外道',
#       'text_en': 'I wanted blood.',
#       'text_zh': '我只是希望報仇雪恨'},
#      {'x': 48,
#       'y': 522,
#       'w': 125,
#       'h': 184,
#       'text_ja': 'そんな奴は何をされたって文句は言えない',
#       'text_en': "People like me don't have a say in how we are treated.",
#       'text_zh': '怎麼對那些人都不算過分'},
#      {'x': 474,
#       'y': 864,
#       'w': 84,
#       'h': 156,
#       'text_ja': 'なんでアンタは銃を捨てない!',
#       'text_en': "why don't you put the gun down!",
#       'text_zh': '你為什麼不丟掉你的槍！'},
#      {'x': 240,
#       'y': 865,
#       'w': 77,
#       'h': 137,
#       'text_ja': 'そんな目にあってまで!!',
#       'text_en': 'look what happened to you!',
#       'text_zh': '你的眼睛都遭受這樣的事情了！ ！'},
#      {'x': 697,
#       'y': 878,
#       'w': 47,
#       'h': 75,
#       'text_ja': 'でもっ',
#       'text_en': 'but...',
#       'text_zh': '但是'},
#      {'x': 570,
#       'y': 1027,
#       'w': 60,
#       'h': 111,
#       'text_ja': 'だったら...',
#       'text_en': 'then...',
#       'text_zh': '所以...'},
#      {'x': 28,
#       'y': 1005,
#       'w': 78,
#       'h': 91,
#       'text_ja': '捨てる?',
#       'text_en': 'put down...?',
#       'text_zh': '扔掉？'}]},
#    {'page_index': 14,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/013.jpg'},
#     'frame': [{'x': 72, 'y': 0, 'w': 757, 'h': 693},
#      {'x': 49, 'y': 703, 'w': 711, 'h': 149},
#      {'x': 523, 'y': 883, 'w': 306, 'h': 286},
#      {'x': 259, 'y': 881, 'w': 261, 'h': 288},
#      {'x': 78, 'y': 881, 'w': 165, 'h': 287}],
#     'text': [{'x': 664,
#       'y': 131,
#       'w': 120,
#       'h': 221,
#       'text_ja': '私にはもう',
#       'text_en': 'what else would I have left?',
#       'text_zh': '我已經'},
#      {'x': 118,
#       'y': 137,
#       'w': 148,
#       'h': 256,
#       'text_ja': '銃と閉じ眼しかないというのに',
#       'text_en': 'if I put down my guns...?',
#       'text_zh': '只剩下槍和封住的眼睛而已'},
#      {'x': 726,
#       'y': 922,
#       'w': 70,
#       'h': 128,
#       'text_ja': '夕飯の準備してくる',
#       'text_en': "I'll go prepare dinner.",
#       'text_zh': '我去準備晚飯'},
#      {'x': 472,
#       'y': 916,
#       'w': 95,
#       'h': 164,
#       'text_ja': '何か不便があったら呼んでくれ',
#       'text_en': 'tell me if you have inconvenience.',
#       'text_zh': '如果有什麼事的話請叫我'}]},
#    {'page_index': 15,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/014.jpg'},
#     'frame': [{'x': 354, 'y': 0, 'w': 400, 'h': 255},
#      {'x': 325, 'y': 4, 'w': 43, 'h': 245},
#      {'x': 0, 'y': 0, 'w': 311, 'h': 257},
#      {'x': 0, 'y': 249, 'w': 775, 'h': 530},
#      {'x': 568, 'y': 767, 'w': 187, 'h': 326},
#      {'x': 412, 'y': 772, 'w': 147, 'h': 323},
#      {'x': 0, 'y': 773, 'w': 393, 'h': 396}],
#     'text': [{'x': 236,
#       'y': 59,
#       'w': 60,
#       'h': 91,
#       'text_ja': 'きっと嘘さ...',
#       'text_en': 'she must be lying.',
#       'text_zh': '一定是謊言'},
#      {'x': 591,
#       'y': 333,
#       'w': 102,
#       'h': 174,
#       'text_ja': '乞食が気を惹くためにつくような嘘',
#       'text_en': 'just like a beggar calling for attention',
#       'text_zh': '就像乞丐為了引人注意裝啞一樣'},
#      {'x': 57,
#       'y': 454,
#       'w': 75,
#       'h': 155,
#       'text_ja': 'そうに決まってる...',
#       'text_en': "yes, it's got to be...",
#       'text_zh': '一定是這樣...'},
#      {'x': 510,
#       'y': 822,
#       'w': 31,
#       'h': 75,
#       'text_ja': '!',
#       'text_en': '!',
#       'text_zh': '！'},
#      {'x': 309,
#       'y': 789,
#       'w': 71,
#       'h': 142,
#       'text_ja': 'も、もうあがったのかい?',
#       'text_en': "you're done already?",
#       'text_zh': '已經洗好了嗎？'},
#      {'x': 253,
#       'y': 868,
#       'w': 74,
#       'h': 163,
#       'text_ja': 'こっちも今できたとこだ',
#       'text_en': "I'm just in time.",
#       'text_zh': '我這兒也準備好了'},
#      {'x': 54,
#       'y': 821,
#       'w': 64,
#       'h': 115,
#       'text_ja': 'いま席に案内をーー',
#       'text_en': "i'll guide you to your seat...",
#       'text_zh': '我帶你去座位上'}]},
#    {'page_index': 16,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/015.jpg'},
#     'frame': [{'x': 470, 'y': 5, 'w': 358, 'h': 488},
#      {'x': 228, 'y': 2, 'w': 216, 'h': 491},
#      {'x': 74, 'y': 75, 'w': 178, 'h': 421},
#      {'x': 59, 'y': 525, 'w': 702, 'h': 123},
#      {'x': 485, 'y': 674, 'w': 344, 'h': 495},
#      {'x': 319, 'y': 677, 'w': 153, 'h': 419},
#      {'x': 78, 'y': 674, 'w': 229, 'h': 490}],
#     'text': [{'x': 722,
#       'y': 49,
#       'w': 83,
#       'h': 180,
#       'text_ja': 'ー‼',
#       'text_en': '!!',
#       'text_zh': '!!'},
#      {'x': 723,
#       'y': 723,
#       'w': 80,
#       'h': 189,
#       'text_ja': 'レーネさーん今あがりましたー',
#       'text_en': "I'm done!",
#       'text_zh': '蕾娜小姐,我好了！'},
#      {'x': 401,
#       'y': 682,
#       'w': 71,
#       'h': 127,
#       'text_ja': 'あっいいかおり',
#       'text_en': 'oh, it smells good.',
#       'text_zh': '啊好香的味道'},
#      {'x': 327,
#       'y': 945,
#       'w': 73,
#       'h': 143,
#       'text_ja': 'ハンバーグのにおいだ',
#       'text_en': 'I can smell hamburg steaks.',
#       'text_zh': '漢堡肉的味道'},
#      {'x': 246,
#       'y': 720,
#       'w': 48,
#       'h': 85,
#       'text_ja': 'あれ?',
#       'text_en': 'huh?',
#       'text_zh': '人呢？'},
#      {'x': 89,
#       'y': 975,
#       'w': 57,
#       'h': 112,
#       'text_ja': 'レーネさーん',
#       'text_en': 'lene?',
#       'text_zh': '蕾娜小姐'}]},
#    {'page_index': 17,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/016.jpg'},
#     'frame': [{'x': 453, 'y': 4, 'w': 305, 'h': 631},
#      {'x': 0, 'y': 3, 'w': 438, 'h': 215},
#      {'x': 0, 'y': 225, 'w': 436, 'h': 217},
#      {'x': 3, 'y': 445, 'w': 435, 'h': 178},
#      {'x': 0, 'y': 644, 'w': 757, 'h': 521}],
#     'text': [{'x': 524,
#       'y': 379,
#       'w': 56,
#       'h': 131,
#       'text_ja': 'くそっ',
#       'text_en': 'shit!',
#       'text_zh': '可惡！'},
#      {'x': 364,
#       'y': 23,
#       'w': 56,
#       'h': 116,
#       'text_ja': '離してよっ',
#       'text_en': 'let go of me!',
#       'text_zh': '放開我'},
#      {'x': 35,
#       'y': 40,
#       'w': 91,
#       'h': 141,
#       'text_ja': 'いきなりなんだってのさ!',
#       'text_en': 'what do you want!',
#       'text_zh': '你要幹什麼！'},
#      {'x': 363,
#       'y': 236,
#       'w': 72,
#       'h': 145,
#       'text_ja': 'そう喚くなよレーネ',
#       'text_en': 'hey, calm down.',
#       'text_zh': '別這樣大呼小叫，蕾娜'},
#      {'x': 32,
#       'y': 232,
#       'w': 105,
#       'h': 182,
#       'text_ja': '用件はうちの弟が散々伝えたと思うがね',
#       'text_en': 'I think my brother told you what I want.',
#       'text_zh': '我想我弟弟已經跟你說了不少這次的事'},
#      {'x': 337,
#       'y': 457,
#       'w': 98,
#       'h': 159,
#       'text_ja': 'だからってここまでされる謂れはないよ',
#       'text_en': "that doesn't give you the reason to go this far",
#       'text_zh': '即使如此，也不能對我這樣'},
#      {'x': 589,
#       'y': 721,
#       'w': 101,
#       'h': 332,
#       'text_ja': 'ドン.トルティヤー!!',
#       'text_en': 'don tortillano !!',
#       'text_zh': '唐·托魯蒂亞諾！ ！'}]},
#    {'page_index': 18,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/017.jpg'},
#     'frame': [{'x': 315, 'y': 2, 'w': 511, 'h': 509},
#      {'x': 77, 'y': 0, 'w': 253, 'h': 516},
#      {'x': 63, 'y': 512, 'w': 766, 'h': 265},
#      {'x': 341, 'y': 800, 'w': 488, 'h': 369},
#      {'x': 74, 'y': 806, 'w': 255, 'h': 363}],
#     'text': [{'x': 716,
#       'y': 85,
#       'w': 61,
#       'h': 120,
#       'text_ja': 'やれやれ',
#       'text_en': 'well, well...',
#       'text_zh': '真是的'},
#      {'x': 364,
#       'y': 180,
#       'w': 108,
#       'h': 184,
#       'text_ja': 'その男勝りな性格はなんとかならんのかね',
#       'text_en': "what's with your manly personality?",
#       'text_zh': '你那好勝的性格能不能改掉'},
#      {'x': 213,
#       'y': 69,
#       'w': 58,
#       'h': 108,
#       'text_ja': 'まあいい',
#       'text_en': 'anyway.',
#       'text_zh': '算了'},
#      {'x': 85,
#       'y': 158,
#       'w': 88,
#       'h': 146,
#       'text_ja': 'そんな君にも買い手がついたんだ',
#       'text_en': "you've got a buyer.",
#       'text_zh': '即使這樣的你也有買主'},
#      {'x': 107,
#       'y': 362,
#       'w': 60,
#       'h': 116,
#       'text_ja': '買い手...?',
#       'text_en': 'buyer...?',
#       'text_zh': '買主...？'},
#      {'x': 655,
#       'y': 532,
#       'w': 126,
#       'h': 176,
#       'text_ja': '君のお父上の絵を買われた方が君のことをえらく気に入ってね',
#       'text_en': "a customer who bought your father's picture really likes you.",
#       'text_zh': '買你父親的畫的人很喜歡你呢'},
#      {'x': 154,
#       'y': 569,
#       'w': 104,
#       'h': 161,
#       'text_ja': 'モデルになった君をぜひ買いたいと',
#       'text_en': 'he told me that he wanted you, because you were the model.',
#       'text_zh': '有人想要買下曾經做過模特的你'},
#      {'x': 723,
#       'y': 841,
#       'w': 69,
#       'h': 114,
#       'text_ja': 'よろこべレーネ',
#       'text_en': "you'd better be happy.",
#       'text_zh': '高興點兒，蕾娜！'},
#      {'x': 359,
#       'y': 943,
#       'w': 110,
#       'h': 157,
#       'text_ja': 'あと数刻で買い手が到着したら借金はチャラだ',
#       'text_en': "the buyer arrives in a few hours, by which time you'll be debt-free",
#       'text_zh': '再過一會兒買主就到了，債務就抵消了'},
#      {'x': 89,
#       'y': 972,
#       'w': 72,
#       'h': 112,
#       'text_ja': 'もっとも',
#       'text_en': 'of course',
#       'text_zh': '可是'}]},
#    {'page_index': 19,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/018.jpg'},
#     'frame': [{'x': 0, 'y': 2, 'w': 751, 'h': 577},
#      {'x': 470, 'y': 621, 'w': 280, 'h': 547},
#      {'x': 194, 'y': 617, 'w': 269, 'h': 552},
#      {'x': 0, 'y': 627, 'w': 183, 'h': 541}],
#     'text': [{'x': 565,
#       'y': 78,
#       'w': 140,
#       'h': 240,
#       'text_ja': '出荷先でどういう扱いを受けるかはわからんがね',
#       'text_en': "i don't know for sure how the buyer will treat you.",
#       'text_zh': '不知道買主會怎麼對你'},
#      {'x': 685,
#       'y': 653,
#       'w': 53,
#       'h': 87,
#       'text_ja': 'ふっ',
#       'text_en': 'wha...',
#       'text_zh': '哼'},
#      {'x': 491,
#       'y': 922,
#       'w': 80,
#       'h': 163,
#       'text_ja': 'ふざけんなっ!',
#       'text_en': 'stop joking with me...!',
#       'text_zh': '開什麼玩笑！'},
#      {'x': 369,
#       'y': 635,
#       'w': 80,
#       'h': 168,
#       'text_ja': 'だっ誰かーー!!',
#       'text_en': 's-someone...!',
#       'text_zh': '有沒有人！ ！'},
#      {'x': 246,
#       'y': 918,
#       'w': 36,
#       'h': 62,
#       'text_ja': 'はっ',
#       'text_en': 'ha',
#       'text_zh': '哈！'},
#      {'x': 204,
#       'y': 968,
#       'w': 60,
#       'h': 132,
#       'text_ja': '無駄だよレーネ',
#       'text_en': "it's no use, lene.",
#       'text_zh': '蕾娜，沒用的！'},
#      {'x': 63,
#       'y': 641,
#       'w': 110,
#       'h': 151,
#       'text_ja': 'こんな街外れの倉庫で叫んだって誰も来やしないさ',
#       'text_en': 'no one would hear you  in this off-town storage.',
#       'text_zh': '這樣偏僻的倉庫，你尖叫也沒有人會來的'}]},
#    {'page_index': 20,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/019.jpg'},
#     'frame': [{'x': 269, 'y': 3, 'w': 555, 'h': 400},
#      {'x': 73, 'y': 0, 'w': 189, 'h': 392},
#      {'x': 66, 'y': 394, 'w': 759, 'h': 185},
#      {'x': 77, 'y': 600, 'w': 752, 'h': 337},
#      {'x': 324, 'y': 934, 'w': 505, 'h': 233},
#      {'x': 76, 'y': 934, 'w': 236, 'h': 234}],
#     'text': [{'x': 737,
#       'y': 59,
#       'w': 53,
#       'h': 94,
#       'text_ja': 'まったく',
#       'text_en': 'oh well,',
#       'text_zh': '真是的'},
#      {'x': 648,
#       'y': 98,
#       'w': 92,
#       'h': 155,
#       'text_ja': 'マヌケは何をされても文句は言えんなぁ',
#       'text_en': 'look how pathetic you are.',
#       'text_zh': '不管受到什麼對待都不會抱怨'},
#      {'x': 298,
#       'y': 154,
#       'w': 120,
#       'h': 168,
#       'text_ja': 'お父上も目を患わなければ生かしておいたものを',
#       'text_en': "and your father. if his eyes weren't so bad I would have let him survive...",
#       'text_zh': '你父親的眼睛要是沒患病'},
#      {'x': 217,
#       'y': 39,
#       'w': 48,
#       'h': 67,
#       'text_ja': 'ど...',
#       'text_en': 'what the...',
#       'text_zh': '這...'},
#      {'x': 88,
#       'y': 222,
#       'w': 77,
#       'h': 136,
#       'text_ja': 'どういう意味さ...',
#       'text_en': "what's that supposed to mean?",
#       'text_zh': '這是什麼意思？'},
#      {'x': 633,
#       'y': 407,
#       'w': 123,
#       'h': 162,
#       'text_ja': 'もう会うこともないだろうから教えてやろう',
#       'text_en': "might as well tell you before we won't see each other again for good",
#       'text_zh': '既然再也不會見面了，我就告訴你吧'},
#      {'x': 683,
#       'y': 601,
#       'w': 105,
#       'h': 182,
#       'text_ja': '君の父親は目を悪くして困っていたからね',
#       'text_en': 'because your father was suffering from his blindness,',
#       'text_zh': '你的父親眼睛日益惡化'},
#      {'x': 557,
#       'y': 693,
#       'w': 132,
#       'h': 193,
#       'text_ja': '治療費の足しに次の絵を高く買ってやろうと言ったんだ',
#       'text_en': 'I offered to buy his picture at a higher price than usual.',
#       'text_zh': '我提出高價買他的下一個作品，作為他的治療費'},
#      {'x': 112,
#       'y': 635,
#       'w': 136,
#       'h': 197,
#       'text_ja': '口約束だけじゃ不安だろうから契約書も用意してやった',
#       'text_en': 'for his convenience, I prepared him a contract',
#       'text_zh': '因為只是口頭約定他可能會不安，準備了紙質的合同'},
#      {'x': 691,
#       'y': 953,
#       'w': 97,
#       'h': 127,
#       'text_ja': 'ただ私もうっかりしていてね',
#       'text_en': 'but, oops, my bad.',
#       'text_zh': '但是我一不小心'},
#      {'x': 337,
#       'y': 950,
#       'w': 102,
#       'h': 141,
#       'text_ja': 'ちょっと紙を間違えてしまった',
#       'text_en': 'i got the wrong kind of paper.',
#       'text_zh': '把合同拿錯了'},
#      {'x': 218,
#       'y': 943,
#       'w': 90,
#       'h': 161,
#       'text_ja': 'まさか目が悪かった彼にも気づけまい',
#       'text_en': 'with his eyes, it was impossible for him to notice',
#       'text_zh': '他的眼睛不好也沒有能注意到'}]},
#    {'page_index': 21,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/020.jpg'},
#     'frame': [{'x': 302, 'y': 7, 'w': 421, 'h': 548},
#      {'x': 2, 'y': 5, 'w': 371, 'h': 559},
#      {'x': 0, 'y': 587, 'w': 809, 'h': 166},
#      {'x': 0, 'y': 776, 'w': 771, 'h': 393}],
#     'text': [{'x': 394,
#       'y': 73,
#       'w': 130,
#       'h': 149,
#       'text_ja': '自分がサインした契約書が',
#       'text_en': 'the contract paper he signed,',
#       'text_zh': '他籤的契約書'},
#      {'x': 44,
#       'y': 62,
#       'w': 119,
#       'h': 183,
#       'text_ja': '多額の借用書だったなんて',
#       'text_en': 'was an IOU for billions.',
#       'text_zh': '是一個巨額的借款契約'},
#      {'x': 627,
#       'y': 608,
#       'w': 111,
#       'h': 122,
#       'text_ja': '待てよ...じゃあ父さんは...',
#       'text_en': 'wait, then was my father...',
#       'text_zh': '等等...那麼我的父親...'},
#      {'x': 21,
#       'y': 597,
#       'w': 169,
#       'h': 134,
#       'text_ja': '視力を無くした画家になんの価値がある?',
#       'text_en': 'do you think a painter without sight is valuable enough?',
#       'text_zh': '沒有視力的畫家還有什麼價值？'},
#      {'x': 641,
#       'y': 794,
#       'w': 102,
#       'h': 186,
#       'text_ja': '可哀想だからあの世に送ってやったよ!',
#       'text_en': "i couldn't help but take his non-valuable life!",
#       'text_zh': '他太可憐了，所以我把他送往了那個世界！'},
#      {'x': 56,
#       'y': 837,
#       'w': 119,
#       'h': 203,
#       'text_ja': '今頃は天使のヌードでも描いてるだろうさ!!',
#       'text_en': "he'd probably be drawing pictures of angel nude now!",
#       'text_zh': '現在應該在畫天使的裸體吧！ ！'}]},
#    {'page_index': 22,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/021.jpg'},
#     'frame': [{'x': 611, 'y': 0, 'w': 216, 'h': 316},
#      {'x': 75, 'y': 0, 'w': 526, 'h': 317},
#      {'x': 248, 'y': 346, 'w': 581, 'h': 245},
#      {'x': 74, 'y': 343, 'w': 165, 'h': 245},
#      {'x': 98, 'y': 609, 'w': 704, 'h': 560}],
#     'text': [{'x': 365,
#       'y': 54,
#       'w': 48,
#       'h': 93,
#       'text_ja': 'あ?',
#       'text_en': 'huh?',
#       'text_zh': '啊？'},
#      {'x': 724,
#       'y': 345,
#       'w': 56,
#       'h': 73,
#       'text_ja': 'ててっ',
#       'text_en': 'ouch!',
#       'text_zh': '好痛'},
#      {'x': 657,
#       'y': 410,
#       'w': 81,
#       'h': 150,
#       'text_ja': '思ったより窓が高かった...',
#       'text_en': 'the window was higher than i thought.',
#       'text_zh': '窗戶比想像的高'},
#      {'x': 198,
#       'y': 355,
#       'w': 46,
#       'h': 65,
#       'text_ja': 'おい...',
#       'text_en': 'hey...',
#       'text_zh': '餵...'},
#      {'x': 75,
#       'y': 357,
#       'w': 64,
#       'h': 84,
#       'text_ja': 'なんだこいつ...',
#       'text_en': "who's this...?",
#       'text_zh': '這傢伙...'},
#      {'x': 662,
#       'y': 669,
#       'w': 136,
#       'h': 284,
#       'text_ja': 'シオラッ!?',
#       'text_en': 'siora?!',
#       'text_zh': '希奧拉！ ？'},
#      {'x': 556,
#       'y': 665,
#       'w': 53,
#       'h': 92,
#       'text_ja': 'いやぁ',
#       'text_en': 'hey',
#       'text_zh': '不好意思'},
#      {'x': 124,
#       'y': 830,
#       'w': 111,
#       'h': 219,
#       'text_ja': '夜分遅くにすいません...',
#       'text_en': 'sorry to visit you this late at night.',
#       'text_zh': '這麼晚打擾了...'}]},
#    {'page_index': 23,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/022.jpg'},
#     'frame': [{'x': 2, 'y': 0, 'w': 762, 'h': 295},
#      {'x': 70, 'y': 319, 'w': 685, 'h': 310},
#      {'x': 472, 'y': 658, 'w': 283, 'h': 511},
#      {'x': 322, 'y': 656, 'w': 138, 'h': 443},
#      {'x': 0, 'y': 659, 'w': 308, 'h': 501}],
#     'text': [{'x': 630,
#       'y': 68,
#       'w': 77,
#       'h': 169,
#       'text_ja': 'こちらにいるレーネさんを',
#       'text_en': 'I just wanted to...',
#       'text_zh': '我是來接'},
#      {'x': 72,
#       'y': 78,
#       'w': 66,
#       'h': 166,
#       'text_ja': '迎えにあがったのですが...',
#       'text_en': 'pick her up...',
#       'text_zh': '蕾娜小姐的...'},
#      {'x': 675,
#       'y': 352,
#       'w': 58,
#       'h': 78,
#       'text_ja': 'あっ兄貴!',
#       'text_en': 'don!',
#       'text_zh': '老...老大'},
#      {'x': 592,
#       'y': 418,
#       'w': 101,
#       'h': 160,
#       'text_ja': 'こいつさっき俺が報告した妙な閉じ眼だ!',
#       'text_en': 'this kid is the closed eyes I told you about!',
#       'text_zh': '這就是我剛才報告的封著眼睛的怪傢伙'},
#      {'x': 287,
#       'y': 376,
#       'w': 63,
#       'h': 96,
#       'text_ja': 'なんだビル',
#       'text_en': 'bill...',
#       'text_zh': '比爾'},
#      {'x': 101,
#       'y': 394,
#       'w': 77,
#       'h': 136,
#       'text_ja': 'つけられたのか?',
#       'text_en': 'were you followed by him?',
#       'text_zh': '你被跟踪了嗎？'},
#      {'x': 654,
#       'y': 671,
#       'w': 88,
#       'h': 131,
#       'text_ja': 'つっつけようったって...',
#       'text_en': "but it can't be possible...",
#       'text_zh': '可是要跟踪的話...'},
#      {'x': 490,
#       'y': 964,
#       'w': 68,
#       'h': 116,
#       'text_ja': 'こいつは眼が...',
#       'text_en': 'his eyes are...',
#       'text_zh': '她這眼睛...'},
#      {'x': 344,
#       'y': 861,
#       'w': 70,
#       'h': 135,
#       'text_ja': '匂いですよ',
#       'text_en': "it's the smell.",
#       'text_zh': '是氣味啊'},
#      {'x': 199,
#       'y': 661,
#       'w': 101,
#       'h': 209,
#       'text_ja': 'レーネさんが作ったハンバーグの美味しそうな香り',
#       'text_en': 'the smell of Hamburg steak she made.',
#       'text_zh': '我是跟著蕾娜小姐製作的漢堡肉的香味'},
#      {'x': 34,
#       'y': 928,
#       'w': 105,
#       'h': 165,
#       'text_ja': 'それを辿ってここまで来てみたら...',
#       'text_en': 'I followed the scent and came here...',
#       'text_zh': '來到這裡的'}]},
#    {'page_index': 24,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/023.jpg'},
#     'frame': [{'x': 69, 'y': 0, 'w': 760, 'h': 237},
#      {'x': 79, 'y': 240, 'w': 743, 'h': 213},
#      {'x': 86, 'y': 445, 'w': 731, 'h': 210},
#      {'x': 578, 'y': 685, 'w': 251, 'h': 411},
#      {'x': 255, 'y': 676, 'w': 344, 'h': 493},
#      {'x': 74, 'y': 680, 'w': 183, 'h': 417}],
#     'text': [{'x': 660,
#       'y': 35,
#       'w': 112,
#       'h': 170,
#       'text_ja': '腐肉を煮詰めたような臭いが充満していて',
#       'text_en': 'but this place is filled with a filthy odor.',
#       'text_zh': '但是這裡充滿了燉爛肉的味道'},
#      {'x': 117,
#       'y': 48,
#       'w': 84,
#       'h': 143,
#       'text_ja': '大変気分が悪い',
#       'text_en': 'gosh, i might not feel very well.',
#       'text_zh': '讓我感覺很噁心呢'},
#      {'x': 664,
#       'y': 253,
#       'w': 105,
#       'h': 182,
#       'text_ja': 'このままではせっかくの夕飯も冷めてしまう',
#       'text_en': "and the dinner will get cold if we don't hurry.",
#       'text_zh': '這樣下去， 難得準備的晚飯會涼的'},
#      {'x': 201,
#       'y': 251,
#       'w': 84,
#       'h': 142,
#       'text_ja': 'お互い銃を抜くことなく',
#       'text_en': 'please let us go in peace.',
#       'text_zh': '不如我們大家都不要激動'},
#      {'x': 116,
#       'y': 289,
#       'w': 91,
#       'h': 157,
#       'text_ja': 'どうか穏便に帰して頂けませんか',
#       'text_en': "it's for the both of us.",
#       'text_zh': '心平氣和地讓我們回家可以嗎？'},
#      {'x': 646,
#       'y': 464,
#       'w': 71,
#       'h': 79,
#       'text_ja': '......',
#       'text_en': '......',
#       'text_zh': '...'},
#      {'x': 606,
#       'y': 512,
#       'w': 57,
#       'h': 106,
#       'text_ja': 'ビル',
#       'text_en': 'bill...',
#       'text_zh': '比爾'},
#      {'x': 139,
#       'y': 485,
#       'w': 57,
#       'h': 102,
#       'text_ja': 'おう',
#       'text_en': 'yeah.',
#       'text_zh': '嗯'},
#      {'x': 706,
#       'y': 708,
#       'w': 109,
#       'h': 140,
#       'text_ja': '状況が全く見えてないマヌケには',
#       'text_en': 'I guess this kid can\'t "see" the situation she\'s in.',
#       'text_zh': '搞不清狀況的傻瓜'},
#      {'x': 588,
#       'y': 948,
#       'w': 87,
#       'h': 143,
#       'text_ja': '鉛弾で思い知らせてやらねばな',
#       'text_en': 'we have to let her know.',
#       'text_zh': '只有讓你嚐嚐這子彈的厲害了'},
#      {'x': 478,
#       'y': 705,
#       'w': 99,
#       'h': 160,
#       'text_ja': '閉じ眼如きが舐めたロききやがって',
#       'text_en': 'this is for making fun of us.',
#       'text_zh': '明明只是個瞎子居然敢看不起我們'},
#      {'x': 85,
#       'y': 692,
#       'w': 63,
#       'h': 149,
#       'text_ja': 'シオラッ!!',
#       'text_en': 'siora!!',
#       'text_zh': '希奧拉！'}]},
#    {'page_index': 25,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/024.jpg'},
#     'frame': [{'x': 480, 'y': 0, 'w': 270, 'h': 821},
#      {'x': 515, 'y': 226, 'w': 235, 'h': 868},
#      {'x': 225, 'y': 57, 'w': 275, 'h': 946},
#      {'x': 268, 'y': 900, 'w': 253, 'h': 267},
#      {'x': 4, 'y': 0, 'w': 231, 'h': 1169}],
#     'text': [{'x': 657,
#       'y': 458,
#       'w': 109,
#       'h': 198,
#       'text_ja': 'くたばれ',
#       'text_en': 'die.',
#       'text_zh': '去死吧！'}]},
#    {'page_index': 26,
#     'image_paths': {'ja': 'images/tojime_no_siora/ja/025.jpg'},
#     'frame': [{'x': 548, 'y': 1, 'w': 279, 'h': 201},
#      {'x': 82, 'y': 0, 'w': 470, 'h': 227},
#      {'x': 110, 'y': 219, 'w': 718, 'h': 188},
# ...
#       'text_en': "you can't have forgotten",
#       'text_zh': '不要忘記啊'},
#      {'x': 104,
#       'y': 761,
#       'w': 98,
#       'h': 200,
#       'text_ja': 'その心にあった想いを',
#       'text_en': 'the thoughts you had in your heart',
#       'text_zh': '在心裡的記憶'}]},
#    {'page_index': 43,
#     'image_paths': {'ja': 'images/rasetugari/ja/042.jpg'},
#     'frame': [{'x': 385, 'y': 6, 'w': 370, 'h': 459},
#      {'x': 78, 'y': 0, 'w': 286, 'h': 469},
#      {'x': 69, 'y': 498, 'w': 692, 'h': 177},
#      {'x': 77, 'y': 693, 'w': 668, 'h': 476}],
#     'text': [{'x': 662,
#       'y': 78,
#       'w': 68,
#       'h': 149,
#       'text_ja': 'そして...',
#       'text_en': 'remember...',
#       'text_zh': '還有...'},
#      {'x': 330,
#       'y': 81,
#       'w': 95,
#       'h': 195,
#       'text_ja': '私がいつもそばにいることを',
#       'text_en': "i'll always be there for you.",
#       'text_zh': '不要忘記我會一直在你身邊陪著你'},
#      {'x': 621,
#       'y': 509,
#       'w': 76,
#       'h': 156,
#       'text_ja': 'くだらん...',
#       'text_en': 'bollocks..',
#       'text_zh': '無聊...'},
#      {'x': 660,
#       'y': 732,
#       'w': 84,
#       'h': 309,
#       'text_ja': '許さんぞ',
#       'text_en': 'this is ',
#       'text_zh': '決不允許'},
#      {'x': 91,
#       'y': 725,
#       'w': 141,
#       'h': 318,
#       'text_ja': 'このような茶番',
#       'text_en': 'unacceptable',
#       'text_zh': '這種事情'}]},
#    {'page_index': 44,
#     'image_paths': {'ja': 'images/rasetugari/ja/043.jpg'},
#     'frame': [{'x': 352, 'y': 9, 'w': 473, 'h': 537},
#      {'x': 77, 'y': 0, 'w': 266, 'h': 330},
#      {'x': 75, 'y': 359, 'w': 271, 'h': 184},
#      {'x': 80, 'y': 563, 'w': 738, 'h': 606}],
#     'text': [{'x': 118,
#       'y': 46,
#       'w': 58,
#       'h': 152,
#       'text_ja': 'ーっ!?',
#       'text_en': 'what?',
#       'text_zh': '咦！ ？'},
#      {'x': 287,
#       'y': 364,
#       'w': 66,
#       'h': 88,
#       'text_ja': '華鏡丸',
#       'text_en': 'kakyomaru',
#       'text_zh': '抱歉了'},
#      {'x': 81,
#       'y': 366,
#       'w': 53,
#       'h': 104,
#       'text_ja': '悪いが...',
#       'text_en': "don't feel bad",
#       'text_zh': '華鏡丸'},
#      {'x': 695,
#       'y': 689,
#       'w': 78,
#       'h': 178,
#       'text_ja': 'ここからは',
#       'text_en': 'but from here on',
#       'text_zh': '接下來'},
#      {'x': 166,
#       'y': 683,
#       'w': 125,
#       'h': 247,
#       'text_ja': 'お前の一人相撲だ',
#       'text_en': "you'll be battling against nothing but yourself",
#       'text_zh': '就是你一個人自彈自唱了'}]},
#    {'page_index': 45,
#     'image_paths': {'ja': 'images/rasetugari/ja/044.jpg'},
#     'frame': [{'x': 58, 'y': 0, 'w': 708, 'h': 281},
#      {'x': 509, 'y': 312, 'w': 244, 'h': 223},
#      {'x': 280, 'y': 310, 'w': 215, 'h': 225},
#      {'x': 75, 'y': 310, 'w': 195, 'h': 223},
#      {'x': 456, 'y': 566, 'w': 299, 'h': 526},
#      {'x': 336, 'y': 573, 'w': 105, 'h': 510},
#      {'x': 78, 'y': 574, 'w': 259, 'h': 519}],
#     'text': [{'x': 646,
#       'y': 17,
#       'w': 91,
#       'h': 137,
#       'text_ja': 'すまない呉葉',
#       'text_en': 'sorry, kureha',
#       'text_zh': '對不起，吳葉'},
#      {'x': 582,
#       'y': 93,
#       'w': 86,
#       'h': 137,
#       'text_ja': '傷...痛むか',
#       'text_en': 'you must be in so much pain',
#       'text_zh': '傷口... 還疼嗎？'},
#      {'x': 321,
#       'y': 42,
#       'w': 62,
#       'h': 118,
#       'text_ja': '証めるな',
#       'text_en': "don't underestimate me.",
#       'text_zh': '不要小看我'},
#      {'x': 94,
#       'y': 24,
#       'w': 124,
#       'h': 194,
#       'text_ja': 'ここで踏ん張れぬほど柔な鍛え方はしておらん',
#       'text_en': "i wasn't that soft training on myself, you know",
#       'text_zh': '受過嚴格訓練的我可不會在這裡雙腿發軟'},
#      {'x': 678,
#       'y': 324,
#       'w': 64,
#       'h': 101,
#       'text_ja': 'そうかならーー',
#       'text_en': 'well... then...',
#       'text_zh': '這樣啊， 既然如此'},
#      {'x': 526,
#       'y': 341,
#       'w': 48,
#       'h': 95,
#       'text_ja': '頼む',
#       'text_en': 'now',
#       'text_zh': '拜託了'},
#      {'x': 445,
#       'y': 320,
#       'w': 46,
#       'h': 75,
#       'text_ja': 'お、おい待て待て',
#       'text_en': 'wait',
#       'text_zh': '喂喂， 等一下'},
#      {'x': 415,
#       'y': 378,
#       'w': 51,
#       'h': 101,
#       'text_ja': '何をするつもりだ',
#       'text_en': 'what are you doing',
#       'text_zh': '你想幹什麼？'},
#      {'x': 237,
#       'y': 349,
#       'w': 57,
#       'h': 140,
#       'text_ja': 'まさかーー',
#       'text_en': 'wait...',
#       'text_zh': '難道...'},
#      {'x': 85,
#       'y': 409,
#       'w': 52,
#       'h': 106,
#       'text_ja': '御意',
#       'text_en': 'yes, sir',
#       'text_zh': '遵命'},
#      {'x': 671,
#       'y': 592,
#       'w': 69,
#       'h': 192,
#       'text_ja': 'やめーー',
#       'text_en': 'stop!',
#       'text_zh': '住手'},
#      {'x': 362,
#       'y': 859,
#       'w': 56,
#       'h': 148,
#       'text_ja': 'ぐっ...',
#       'text_en': 'unh...',
#       'text_zh': '嗚...'},
#      {'x': 80,
#       'y': 575,
#       'w': 91,
#       'h': 251,
#       'text_ja': 'おあーー!!',
#       'text_en': 'aaaahhhhhhhhhhhhhhhh!!!!',
#       'text_zh': '嗚啊啊啊！ ！'}]},
#    {'page_index': 46,
#     'image_paths': {'ja': 'images/rasetugari/ja/045.jpg'},
#     'frame': [{'x': 294, 'y': 0, 'w': 466, 'h': 356},
#      {'x': 77, 'y': 4, 'w': 207, 'h': 349},
#      {'x': 453, 'y': 386, 'w': 301, 'h': 261},
#      {'x': 70, 'y': 386, 'w': 373, 'h': 260},
#      {'x': 473, 'y': 677, 'w': 276, 'h': 490},
#      {'x': 77, 'y': 669, 'w': 388, 'h': 500}],
#     'text': [{'x': 339,
#       'y': 44,
#       'w': 51,
#       'h': 102,
#       'text_ja': 'ああ...',
#       'text_en': 'oh, god.',
#       'text_zh': '啊啊...'},
#      {'x': 218,
#       'y': 55,
#       'w': 72,
#       'h': 114,
#       'text_ja': '呪いがーー',
#       'text_en': 'the curse...',
#       'text_zh': '詛咒'},
#      {'x': 128,
#       'y': 149,
#       'w': 53,
#       'h': 96,
#       'text_ja': '境気が',
#       'text_en': 'the evil spirit',
#       'text_zh': '瘴氣'},
#      {'x': 84,
#       'y': 190,
#       'w': 56,
#       'h': 139,
#       'text_ja': '妄執が燃えていく...',
#       'text_en': "the obsession, it's burning away...",
#       'text_zh': '執念全部燃燒了'},
#      {'x': 479,
#       'y': 439,
#       'w': 62,
#       'h': 142,
#       'text_ja': 'もったいない',
#       'text_en': 'what a waste.',
#       'text_zh': '太浪費了'},
#      {'x': 349,
#       'y': 397,
#       'w': 80,
#       'h': 149,
#       'text_ja': 'もったいないもったいない',
#       'text_en': 'what a waste. what a waste.',
#       'text_zh': '太浪費了太浪費了'},
#      {'x': 83,
#       'y': 406,
#       'w': 71,
#       'h': 158,
#       'text_ja': 'もったいないもったいないもったいない...',
#       'text_en': 'what a waste, what a waste, what a waste...',
#       'text_zh': '太浪費了太浪費了太浪費了...'},
#      {'x': 673,
#       'y': 695,
#       'w': 71,
#       'h': 178,
#       'text_ja': 'おのれぇぇえええええ!!',
#       'text_en': 'damn you!',
#       'text_zh': '可惡啊啊啊啊啊！ ！'},
#      {'x': 446,
#       'y': 720,
#       'w': 68,
#       'h': 195,
#       'text_ja': 'この上なき憎悪を果てしなき怨睦を',
#       'text_en': 'all the splendid hatred',
#       'text_zh': '至高的憎惡， 無果的嗟怨，'},
#      {'x': 368,
#       'y': 781,
#       'w': 76,
#       'h': 188,
#       'text_ja': '極上の妄執を',
#       'text_en': 'the wonderful obsession\n...',
#       'text_zh': '極上的執念，'},
#      {'x': 106,
#       'y': 710,
#       'w': 75,
#       'h': 224,
#       'text_ja': 'お前が無駄にしたものの味',
#       'text_en': "you've wasted all my precious food",
#       'text_zh': '這些讓你白白浪費的東西的味道'}]},
#    {'page_index': 47,
#     'image_paths': {'ja': 'images/rasetugari/ja/046.jpg'},
#     'frame': [{'x': 0, 'y': 0, 'w': 749, 'h': 482},
#      {'x': 78, 'y': 509, 'w': 673, 'h': 203},
#      {'x': 551, 'y': 743, 'w': 203, 'h': 352},
#      {'x': 273, 'y': 741, 'w': 263, 'h': 353},
#      {'x': 76, 'y': 746, 'w': 219, 'h': 340}],
#     'text': [{'x': 642,
#       'y': 35,
#       'w': 105,
#       'h': 224,
#       'text_ja': 'とくと',
#       'text_en': 'do ...',
#       'text_zh': '讓我'},
#      {'x': 15,
#       'y': 21,
#       'w': 122,
#       'h': 453,
#       'text_ja': '味わうがいい！！',
#       'text_en': 'have a little taste!!!',
#       'text_zh': '嘗上一點啊！ ！'},
#      {'x': 651,
#       'y': 543,
#       'w': 79,
#       'h': 121,
#       'text_ja': '妄執の味なら',
#       'text_en': 'i already know',
#       'text_zh': '執念的味道'},
#      {'x': 109,
#       'y': 542,
#       'w': 73,
#       'h': 118,
#       'text_ja': 'もう知った',
#       'text_en': 'that taste of obsession',
#       'text_zh': '我已經知道了'},
#      {'x': 664,
#       'y': 745,
#       'w': 88,
#       'h': 165,
#       'text_ja': '痛みを忘れて憎悪に酔うのは',
#       'text_en': 'getting drunk in hatred, and forgetting the pain',
#       'text_zh': '忘記疼痛沉浸在憎恨中的味道'},
#      {'x': 548,
#       'y': 942,
#       'w': 106,
#       'h': 145,
#       'text_ja': '確かに甘美だったぞ華鏡丸',
#       'text_en': 'indeed it was sweet and easy, kakyomaru',
#       'text_zh': '的確很甘美啊，華鏡丸'},
#      {'x': 461,
#       'y': 784,
#       'w': 53,
#       'h': 120,
#       'text_ja': 'だが',
#       'text_en': 'but...',
#       'text_zh': '不過'},
#      {'x': 95,
#       'y': 932,
#       'w': 55,
#       'h': 128,
#       'text_ja': 'もうやめだ',
#       'text_en': "I won't fall for it",
#       'text_zh': '我已經不會再那樣了'}]},
#    {'page_index': 48,
#     'image_paths': {'ja': 'images/rasetugari/ja/047.jpg'},
#     'frame': [{'x': 0, 'y': 48, 'w': 828, 'h': 1121}],
#     'text': [{'x': 580,
#       'y': 174,
#       'w': 144,
#       'h': 309,
#       'text_ja': '俺はもう',
#       'text_en': 'i will not',
#       'text_zh': '我已經'}]},
#    {'page_index': 49,
#     'image_paths': {'ja': 'images/rasetugari/ja/048.jpg'},
#     'frame': [{'x': 0, 'y': 0, 'w': 829, 'h': 1135}],
#     'text': [{'x': 115,
#       'y': 164,
#       'w': 172,
#       'h': 370,
#       'text_ja': '想いを見失わぬ',
#       'text_en': 'not any more.',
#       'text_zh': '不想再失去珍貴的回憶了'}]},
#    {'page_index': 50,
#     'image_paths': {'ja': 'images/rasetugari/ja/049.jpg'},
#     'frame': [{'x': 629, 'y': 2, 'w': 125, 'h': 346},
#      {'x': 73, 'y': 0, 'w': 560, 'h': 343},
#      {'x': 454, 'y': 376, 'w': 298, 'h': 220},
#      {'x': 73, 'y': 378, 'w': 370, 'h': 216},
#      {'x': 307, 'y': 635, 'w': 450, 'h': 454},
#      {'x': 74, 'y': 625, 'w': 228, 'h': 466}],
#     'text': [{'x': 623,
#       'y': 659,
#       'w': 85,
#       'h': 158,
#       'text_ja': 'ーー呉葉',
#       'text_en': '--kureha',
#       'text_zh': '吳葉'},
#      {'x': 228,
#       'y': 658,
#       'w': 58,
#       'h': 140,
#       'text_ja': '...なんだ',
#       'text_en': '...\nwhat?',
#       'text_zh': '怎麼了？'}]},
#    {'page_index': 51,
#     'image_paths': {'ja': 'images/rasetugari/ja/050.jpg'},
#     'frame': [{'x': 77, 'y': 0, 'w': 686, 'h': 382},
#      {'x': 338, 'y': 415, 'w': 416, 'h': 300},
#      {'x': 75, 'y': 413, 'w': 250, 'h': 300},
#      {'x': 277, 'y': 742, 'w': 481, 'h': 353},
#      {'x': 74, 'y': 741, 'w': 190, 'h': 355}],
#     'text': [{'x': 636,
#       'y': 76,
#       'w': 71,
#       'h': 143,
#       'text_ja': '重い',
#       'text_en': "you're heavy",
#       'text_zh': '好重'},
#      {'x': 92,
#       'y': 25,
#       'w': 141,
#       'h': 267,
#       'text_ja': 'お前言うに事欠いてそれかぁーー!!',
#       'text_en': "is that all you've got to say?",
#       'text_zh': '這種事情就不要說出來了啊啊！ ！'},
#      {'x': 636,
#       'y': 426,
#       'w': 104,
#       'h': 170,
#       'text_ja': '事欠くもなにも腕の火傷は痛むしもうヘトヘトだ',
#       'text_en': "i mean, the burns on my arm hurt, and i'm exhausted.",
#       'text_zh': '不是啊， 我手臂的傷也很痛， 已經超累的了'},
#      {'x': 354,
#       'y': 455,
#       'w': 89,
#       'h': 173,
#       'text_ja': 'せめて霊体化してくれ...',
#       'text_en': "can't you turn into your spirit form?",
#       'text_zh': '至少給我靈體化...'},
#      {'x': 267,
#       'y': 473,
#       'w': 43,
#       'h': 80,
#       'text_ja': 'ふん',
#       'text_en': 'hmm',
#       'text_zh': '哼！'},
#      {'x': 98,
#       'y': 518,
#       'w': 64,
#       'h': 101,
#       'text_ja': 'これは罰だ',
#       'text_en': 'this is a punishment.',
#       'text_zh': '這是懲罰'},
#      {'x': 666,
#       'y': 776,
#       'w': 74,
#       'h': 156,
#       'text_ja': '私に刃を向けた罰',
#       'text_en': 'you pointed your blade at me',
#       'text_zh': '這是你把刀刃指向我的懲罰'},
#      {'x': 288,
#       'y': 758,
#       'w': 87,
#       'h': 181,
#       'text_ja': '家まではこうさせてもらうぞ',
#       'text_en': 'your punishment is to take me home like this',
#       'text_zh': '到家之前就一直這樣背著我吧'},
#      {'x': 154,
#       'y': 754,
#       'w': 100,
#       'h': 159,
#       'text_ja': 'しばらくは尻に敷かせてもらわんとな',
#       'text_en': 'you have to take my orders for a while',
#       'text_zh': '暫時就麻煩托著我的屁股啦'},
#      {'x': 104,
#       'y': 944,
#       'w': 48,
#       'h': 105,
#       'text_ja': '呉葉...',
#       'text_en': 'kureha...',
#       'text_zh': '吳葉...'}]},
#    {'page_index': 52,
#     'image_paths': {'ja': 'images/rasetugari/ja/051.jpg'},
#     'frame': [{'x': 377, 'y': 5, 'w': 442, 'h': 449},
#      {'x': 76, 'y': 1, 'w': 289, 'h': 454},
#      {'x': 73, 'y': 482, 'w': 690, 'h': 185},
#      {'x': 72, 'y': 692, 'w': 694, 'h': 407}],
#     'text': [{'x': 692,
#       'y': 86,
#       'w': 77,
#       'h': 183,
#       'text_ja': '俺は弱い',
#       'text_en': "i'm weak.",
#       'text_zh': '我太弱了'},
#      {'x': 249,
#       'y': 10,
#       'w': 113,
#       'h': 187,
#       'text_ja': '華鏡丸を討ったときには見栄を張ったが',
#       'text_en': 'i was ostentatious today, facing kakyomaru,',
#       'text_zh': '討伐華鏡丸時， 我雖然表面很有氣場'},
#      {'x': 80,
#       'y': 276,
#       'w': 88,
#       'h': 161,
#       'text_ja': 'いつまた己を見失いお前を傷つけるかわからぬ',
#       'text_en': 'but i could lose sanity anytime.\nI could even hurt you again.',
#       'text_zh': '但又不知不覺失去了自我，還傷害了你'},
#      {'x': 619,
#       'y': 515,
#       'w': 69,
#       'h': 118,
#       'text_ja': '俺にはもう',
#       'text_en': "i can't...",
#       'text_zh': '我已經'},
#      {'x': 148,
#       'y': 500,
#       'w': 78,
#       'h': 151,
#       'text_ja': 'お前を扱う資格などーー',
#       'text_en': 'i have no right to be your master',
#       'text_zh': '沒有資格繼續當你的...'},
#      {'x': 610,
#       'y': 756,
#       'w': 84,
#       'h': 178,
#       'text_ja': 'たわけ',
#       'text_en': 'idiot',
#       'text_zh': '蠢貨'},
#      {'x': 122,
#       'y': 746,
#       'w': 132,
#       'h': 199,
#       'text_ja': '今さら小童の軟弱さなど承知の上だ',
#       'text_en': "i'm well aware of your weaknesses.",
#       'text_zh': '事到如今你才看清自己像孩子一樣軟弱啊！'}]},
#    {'page_index': 53,
#     'image_paths': {'ja': 'images/rasetugari/ja/052.jpg'},
#     'frame': [{'x': 461, 'y': 0, 'w': 290, 'h': 424},
#      {'x': 77, 'y': 0, 'w': 377, 'h': 425},
#      {'x': 81, 'y': 442, 'w': 674, 'h': 644}],
#     'text': [{'x': 631,
#       'y': 5,
#       'w': 110,
#       'h': 209,
#       'text_ja': '月なき夜に道を外れてしまうこともあろう',
#       'text_en': 'at times, you may lose the track on a moonless night',
#       'text_zh': '沒有月亮的晚上人是會走岔路的'},
#      {'x': 490,
#       'y': 52,
#       'w': 70,
#       'h': 159,
#       'text_ja': 'そんなときのために私がいる',
#       'text_en': "but that is what i'm here for",
#       'text_zh': '我就是為了這種時候而存在的啊'},
#      {'x': 347,
#       'y': 47,
#       'w': 76,
#       'h': 160,
#       'text_ja': '平安の世より在藤に仕えて',
#       'text_en': "I've served the house of arifuji since the heian period",
#       'text_zh': '我從平安時代開始侍奉你們在藤家'},
#      {'x': 102,
#       'y': 86,
#       'w': 64,
#       'h': 147,
#       'text_ja': '早千年',
#       'text_en': 'for a thousand years.',
#       'text_zh': '已有千年'},
#      {'x': 588,
#       'y': 566,
#       'w': 103,
#       'h': 232,
#       'text_ja': '千歳の想いが',
#       'text_en': "the millennium's worth affection",
#       'text_zh': '我千歲的思緒'},
#      {'x': 132,
#       'y': 566,
#       'w': 109,
#       'h': 268,
#       'text_ja': 'お前の審火だ!',
#       'text_en': 'will be your beacon of light!',
#       'text_zh': '就是你的篝火啊！'}]},
#    {'page_index': 54,
#     'image_paths': {'ja': 'images/rasetugari/ja/053.jpg'},
#     'frame': [{'x': 401, 'y': 7, 'w': 428, 'h': 626},
#      {'x': 76, 'y': 3, 'w': 320, 'h': 639},
#      {'x': 75, 'y': 662, 'w': 680, 'h': 432}],
#     'text': [{'x': 362,
#       'y': 81,
#       'w': 84,
#       'h': 174,
#       'text_ja': 'なるほど...',
#       'text_en': 'i see...',
#       'text_zh': '原來如此'},
#      {'x': 96,
#       'y': 96,
#       'w': 88,
#       'h': 210,
#       'text_ja': 'こりゃかなわん',
#       'text_en': 'you beat me',
#       'text_zh': '我了解了'},
#      {'x': 637,
#       'y': 736,
#       'w': 80,
#       'h': 108,
#       'text_ja': 'さて',
#       'text_en': 'well!\n',
#       'text_zh': '那麼'},
#      {'x': 551,
#       'y': 757,
#       'w': 93,
#       'h': 176,
#       'text_ja': 'さて明日は墓掃除だ!',
#       'text_en': 'tomorrow we clean the graves!',
#       'text_zh': '明天是墓地大掃除！'},
#      {'x': 190,
#       'y': 721,
#       'w': 80,
#       'h': 136,
#       'text_ja': 'こ、こら',
#       'text_en': 'hey!!!',
#       'text_zh': '喂喂'},
#      {'x': 117,
#       'y': 799,
#       'w': 86,
#       'h': 155,
#       'text_ja': '急に走るな!',
#       'text_en': "don't start running all of a sudden!",
#       'text_zh': '不要突然跑起來啊！'}]}]}]

# %%
# Open the file in read mode
with open('open-mantra-dataset/text_file.txt', 'r', encoding='utf-8') as file:
    # Read all lines from the file
    lines = file.readlines()

# Initialize an empty set to store unique characters
unique_characters = set()

# Iterate through each line
for line in lines:
    # Split the line based on the tab character (\t)
    parts = line.split('\t')
    
    # Extract the characters after the tab and before the newline
    if len(parts) > 1:
        characters = parts[1].strip()
        
        # Add each character to the set
        unique_characters.update(characters)

# Print the unique characters
print("Unique characters:", unique_characters)
# Out:
# Unique characters: {'程', '受', '下', '駄', '稽', '緒', 'へ', 'ち', '探', '銃', '力', '長', '療', 'チ', '故', '仕', '死', 'ら', '恩', '好', '大', '郷', '名', '末', '散', '高', '7', 'み', '朽', '荒', '誰', '背', 'ぞ', 'ズ', '比', '夜', '借', 'の', '介', 'る', '席', '契', 'ご', 'う', 'ネ', '美', '瞼', '迎', '書', '俺', '同', '腰', '取', '遅', '思', '捨', '外', 'タ', '辿', 'イ', 'ク', '始', '自', '人', 'は', 'ず', '食', 'ょ', '身', 'ト', '々', '絶', '以', '!', '紙', '心', '宿', '飛', '持', '煮', 'ド', '呼', '見', 'ろ', '馬', 'ノ', 'そ', '世', '患', '鉛', '少', 'た', '畜', 'ッ', '概', '君', 'ャ', '回', '咎', '約', '絵', '薄', '仇', '満', '件', '窓', '私', 'ぁ', '費', '払', '分', '減', '親', '物', '想', '打', '討', 'ミ', '日', '器', 'ヌ', '時', '庫', '買', '冷', 'で', '量', '弟', '勝', '変', '丈', '恐', 'ジ', 'ぉ', '五', 'バ', '音', '天', 'ふ', '勘', '撃', '川', 'く', '哀', '視', '我', '嬉', '厄', '案', '意', 'ー', '七', '明', '使', '帰', '妙', 'め', '貰', '前', '切', 'フ', '互', '昔', '声', '追', 'オ', '巨', '嘘', '鹿', 'ル', '伝', 'あ', '貴', 'テ', 'グ', 'ア', '家', '望', '待', '夫', '匂', '教', '逃', 'に', '棒', '全', '終', '汽', '困', '血', 'づ', 'せ', '可', '旅', '画', '描', 'ん', '党', '売', '弾', 'シ', '綴', 'コ', '病', '気', '口', '合', '情', '潰', '直', '上', '夕', '中', '街', '局', '惹', '脳', 'ウ', '況', '畷', 'ワ', 'い', '如', '談', 'ぶ', '焼', '一', '今', '洗', '卸', 'を', '復', '足', 'ざ', '備', '果', '悟', '丸', 'デ', '道', '乞', '数', 'つ', '荷', 'ビ', 'ョ', '出', '離', 'な', '準', 'だ', 'リ', '間', 'カ', '正', '穏', 'ぱ', 'ぇ', '安', '詰', '罪', '倉', '来', '決', '片', '生', '漢', '額', '格', 'す', '先', 'ハ', '舐', '返', '着', '性', '晩', '帯', '刻', '巻', '臭', '言', '対', '博', '入', '助', 'や', '霊', '良', '転', '父', 'ほ', '束', 'れ', '送', '閉', '知', 'わ', '重', '味', '貿', '讐', 'マ', '用', 'お', '申', '面', 'ぜ', '当', '到', '結', '次', '状', '叫', '金', '?', '女', 'ィ', '劇', 'こ', 'と', '・', '、', '娘', 'じ', 'ボ', '値', '喚', '兄', '闇', 'も', 'ひ', 'ラ', '眼', '皆', '.', 'べ', '雇', '許', 'か', 'し', '悲', 'ゃ', '告', '内', '縫', 'ン', 'ガ', 'ね', 'モ', '構', 'キ', '男', '違', '寂', '謂', 'ど', '目', '求', '方', '香', 'ケ', 'ァ', '奴', 'ロ', '何', '悔', '汚', 'き', 'り', '度', 'え', '‼', '覚', '元', '多', '引', '聞', '充', '滑', 'よ', '無', 'サ', '亡', 'ス', '冗', '向', 'さ', '続', '裸', '」', '腕', '証', 'ま', '悪', '抜', '文', '便', 'け', '頂', '車', '作', '侮', 'ば', 'が', 'ヤ', '成', '会', '扱', '礼', '腐', 'ぐ', '怪', '事', '句', '手', '飯', 'レ', '挙', '流', '慣', '行', '確', 'ぽ', '番', '報', '肉', '不', '込', '鷹', '彼', '割', 'っ', '価', '治', '頃', '体', '滅', '殺', '「', 'て'}

# %%
len(unique_characters)
# Out:
# 441

# %%
import os
import cv2
from xml.etree import ElementTree as ET

def crop_images(data_path, output_path):
    annotations_folder = os.path.join(data_path, 'annotations')
    images_folder = os.path.join(data_path, 'images')

    if not os.path.exists(output_path):
        os.makedirs(output_path)

    output_file_path = os.path.join(output_path, 'crop_info.txt')
    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        for annotation_file in os.listdir(annotations_folder):
            if annotation_file.endswith('.xml'):
                xml_path = os.path.join(annotations_folder, annotation_file)
                tree = ET.parse(xml_path)
                root = tree.getroot()

                book_title = root.get('title')
                pages = root.findall('.//page')

                for page in pages:
                    page_index = page.get('index')
                    image_path = os.path.join(images_folder, f'{book_title}/{page_index.zfill(3)}.jpg')

                    image = cv2.imread(image_path)
                    if image is None:
                        continue

                    for text_element in page.findall('.//text'):
                        xmin = int(text_element.get('xmin'))
                        ymin = int(text_element.get('ymin'))
                        xmax = int(text_element.get('xmax'))
                        ymax = int(text_element.get('ymax'))

                        cropped_image = image[ymin:ymax, xmin:xmax]
                        cropped_text = text_element.text.strip()

                        if cropped_text and cropped_image.size > 0:
                            crop_output_path = os.path.join(output_path, f'{book_title}_{page_index}_{text_element.get("id")}.jpg')
                            cv2.imwrite(crop_output_path, cropped_image)

                            output_file.write(f'{crop_output_path}\t{cropped_text}\n')

if __name__ == '__main__':
    data_path = 'Manga109s/Manga109s_released_2023_12_07/'
    output_path = 'crops'

    crop_images(data_path, output_path)

# %%
tree = ET.parse("Manga109s/Manga109s_released_2023_12_07/annotations/AisazuNihaIrarenai.xml")
root = tree.getroot()

# %%
root
# Out:
# <Element 'book' at 0x000002319577C4A0>

# %%
book_title = root.get('title')

# %%
book_title
# Out:
# 'AisazuNihaIrarenai'

# %%
import os
import xml.etree.ElementTree as ET
from shutil import copyfile

def parse_annotations(xml_path, image_width, image_height):
    tree = ET.parse(xml_path)
    root = tree.getroot()

    annotations = []
    for page in root.findall('./pages/page'):
        page_index = page.get('index')
        text_elements = page.findall('./text')
        for text_elem in text_elements:
            text = text_elem.text.strip()
            bbox_elem = text_elem.find('../frame')
            xmin = float(bbox_elem.get('xmin'))
            ymin = float(bbox_elem.get('ymin'))
            xmax = float(bbox_elem.get('xmax'))
            ymax = float(bbox_elem.get('ymax'))
            
            # Normalize bounding box coordinates
            normalized_xmin = xmin / image_width
            normalized_ymin = ymin / image_height
            normalized_xmax = xmax / image_width
            normalized_ymax = ymax / image_height

            annotations.append((page_index, text, normalized_xmin, normalized_ymin, normalized_xmax, normalized_ymax))
    
    return annotations

def convert_to_yolo_format(image_folder, annotation_folder, output_folder):
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for book_folder in os.listdir(annotation_folder):
        book_annotations_path = os.path.join(annotation_folder, book_folder, f'{book_folder}.xml')
        print("run")
        if os.path.isfile(book_annotations_path):
            file_name = os.path.splitext(book_folder)[0]
            image_path = os.path.join(image_folder, f'{file_name}.jpg')
            image_width, image_height = get_image_dimensions(image_path)
            annotations = parse_annotations(book_annotations_path, image_width, image_height)

            with open(os.path.join(output_folder, f'{file_name}.txt'), 'w') as yolo_file:
                for _, text, normalized_xmin, normalized_ymin, normalized_xmax, normalized_ymax in annotations:
                    yolo_file.write(f'{text} {normalized_xmin} {normalized_ymin} {normalized_xmax} {normalized_ymax}\n')
                    
            copyfile(image_path, os.path.join(output_folder, f'{file_name}.jpg'))

def get_image_dimensions(image_path):
    from PIL import Image
    with Image.open(image_path) as img:
        return img.size

# if __name__ == "__main__":
data_folder = "Manga109s\Manga109s_released_2023_12_07"
new_data_folder = "new_data"

images_folder = os.path.join(data_folder, 'images')
annotations_folder = os.path.join(data_folder, 'annotations')

new_images_folder = os.path.join(new_data_folder, 'images')
new_labels_folder = os.path.join(new_data_folder, 'labels')

if not os.path.exists(new_images_folder):
    os.makedirs(new_images_folder)

if not os.path.exists(new_labels_folder):
    os.makedirs(new_labels_folder)

convert_to_yolo_format(images_folder, annotations_folder, new_data_folder)
# Out:
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
