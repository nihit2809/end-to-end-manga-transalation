# %%
import fitz 
from PIL import Image
import onnxruntime as ort

import cv2
import warnings
import numpy as np
from PIL import Image

warnings.filterwarnings("ignore")

def pdf_to_images(pdf_path, image_folder):
    pdf_document = fitz.open(pdf_path)
    for page_number in range(pdf_document.page_count):
        page = pdf_document[page_number]
        image = page.get_pixmap()
        pil_image = Image.frombytes("RGB", [image.width, image.height], image.samples)
        image_path = f"{image_folder}/page_{page_number + 1}.png"
        pil_image.save(image_path, "PNG")

    pdf_document.close()

    
def xywh2xyxy(x):
        y = np.copy(x)
        y[..., 0] = x[..., 0] - x[..., 2] / 2
        y[..., 1] = x[..., 1] - x[..., 3] / 2
        y[..., 2] = x[..., 0] + x[..., 2] / 2
        y[..., 3] = x[..., 1] + x[..., 3] / 2
        return y

    
def nms(boxes, scores, iou_threshold):
    sorted_indices = np.argsort(scores)[::-1]

    keep_boxes = []
    while sorted_indices.size > 0:
        box_id = sorted_indices[0]
        keep_boxes.append(box_id)

        ious = compute_iou(boxes[box_id, :], boxes[sorted_indices[1:], :])

        keep_indices = np.where(ious < iou_threshold)[0]

        sorted_indices = sorted_indices[keep_indices + 1]

    return keep_boxes

def compute_iou(box, boxes):
    xmin = np.maximum(box[0], boxes[:, 0])
    ymin = np.maximum(box[1], boxes[:, 1])
    xmax = np.minimum(box[2], boxes[:, 2])
    ymax = np.minimum(box[3], boxes[:, 3])

    intersection_area = np.maximum(0, xmax - xmin) * np.maximum(0, ymax - ymin)

    box_area = (box[2] - box[0]) * (box[3] - box[1])
    boxes_area = (boxes[:, 2] - boxes[:, 0]) * (boxes[:, 3] - boxes[:, 1])
    union_area = box_area + boxes_area - intersection_area

    iou = intersection_area / union_area

    return iou    
    

def yolo_infer(ort_session,image_path):
    model_inputs = ort_session.get_inputs()
    input_names = [model_inputs[i].name for i in range(len(model_inputs))]
    input_shape = model_inputs[0].shape

    model_output = ort_session.get_outputs()
    output_names = [model_output[i].name for i in range(len(model_output))]
    
    image = cv2.imread(image_path)
    image_height, image_width = image.shape[:2]

    input_height, input_width = input_shape[2:]
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(image_rgb, (input_width, input_height))

    input_image = resized / 255.0
    input_image = input_image.transpose(2,0,1)
    input_tensor = input_image[np.newaxis, :, :, :].astype(np.float32)

    outputs = ort_session.run(output_names, {input_names[0]: input_tensor})[0]
    predictions = np.squeeze(outputs).T
    conf_thresold = 0.65
    scores = np.max(predictions[:, 4:], axis=1)
    predictions = predictions[scores > conf_thresold, :]
    scores = scores[scores > conf_thresold] 

    class_ids = np.argmax(predictions[:, 4:], axis=1)

    boxes = predictions[:, :4]

    input_shape = np.array([input_width, input_height, input_width, input_height])
    boxes = np.divide(boxes, input_shape, dtype=np.float32)
    boxes *= np.array([image_width, image_height, image_width, image_height])
    boxes = boxes.astype(np.int32)
    
    indices = nms(boxes, scores, 0.3)

    CLASSES = [
    "text"
    ]

    bbox_values = []
    score_values = []
    label_values = []

    i=0
    image_draw = image.copy()
    image_draw_2 = image.copy()
    value = image_path.split("/")[-1].split(".")[0]
    for (bbox, score, label) in zip(xywh2xyxy(boxes[indices]), scores[indices], class_ids[indices]):
        bbox = bbox.round().astype(np.int32).tolist()
        bbox_values.append(bbox)
        score_values.append(score)
        cls_id = int(label)
        cls = CLASSES[cls_id]
        label_values.append(cls)
        if cls =="text":
            x1, y1, x2, y2 = bbox
            img = image_draw[y1:y2, x1:x2]
            cv2.rectangle(image_draw_2, (x1, y1), (x2, y2), (255, 0, 0), 2)
            input_image = Image.fromarray(img)
            cv2.imwrite(f"crops_sample/{value}-{i}"+".jpg",img)
        i+=1
    cv2.imwrite(f"plots/{value}.jpg", image_draw_2)

    
if __name__ == "__main__":
    pdf_file_path = 'Black Clover Vol. 1.pdf'

    output_folder = 'output_images'

    import os
    os.makedirs(output_folder, exist_ok=True)

    pdf_to_images(pdf_file_path, output_folder)
    print("Conversion completed.")
    
    model_path = "open-mantra-dataset/best.onnx"
    ort_session = ort.InferenceSession(model_path)
    os.makedirs("crops_sample", exist_ok=True)
    os.makedirs("plots", exist_ok=True)
    for i in os.listdir("output_images"):
        print(f"Running object detection inference over page {i}.")
        yolo_infer(ort_session,"output_images/"+i)
# Out:
# Conversion completed.
# Running object detection inference over page page_1.png.
# Running object detection inference over page page_10.png.
# Running object detection inference over page page_100.png.
# Running object detection inference over page page_101.png.
# Running object detection inference over page page_102.png.
# Running object detection inference over page page_103.png.
# Running object detection inference over page page_104.png.
# Running object detection inference over page page_105.png.
# Running object detection inference over page page_106.png.
# Running object detection inference over page page_107.png.
# Running object detection inference over page page_108.png.
# Running object detection inference over page page_109.png.
# Running object detection inference over page page_11.png.
# Running object detection inference over page page_110.png.
# Running object detection inference over page page_111.png.
# Running object detection inference over page page_112.png.
# Running object detection inference over page page_113.png.
# Running object detection inference over page page_114.png.
# Running object detection inference over page page_115.png.
# Running object detection inference over page page_116.png.
# Running object detection inference over page page_117.png.
# Running object detection inference over page page_118.png.
# Running object detection inference over page page_119.png.
# Running object detection inference over page page_12.png.
# Running object detection inference over page page_120.png.
# Running object detection inference over page page_121.png.
# Running object detection inference over page page_122.png.
# Running object detection inference over page page_123.png.
# Running object detection inference over page page_124.png.
# Running object detection inference over page page_125.png.
# Running object detection inference over page page_126.png.
# Running object detection inference over page page_127.png.
# Running object detection inference over page page_128.png.
# Running object detection inference over page page_129.png.
# Running object detection inference over page page_13.png.
# Running object detection inference over page page_130.png.
# Running object detection inference over page page_131.png.
# Running object detection inference over page page_132.png.
# Running object detection inference over page page_133.png.
# Running object detection inference over page page_134.png.
# Running object detection inference over page page_135.png.
# Running object detection inference over page page_136.png.
# Running object detection inference over page page_137.png.
# Running object detection inference over page page_138.png.
# Running object detection inference over page page_139.png.
# Running object detection inference over page page_14.png.
# Running object detection inference over page page_140.png.
# Running object detection inference over page page_141.png.
# Running object detection inference over page page_142.png.
# Running object detection inference over page page_143.png.
# Running object detection inference over page page_144.png.
# Running object detection inference over page page_145.png.
# Running object detection inference over page page_146.png.
# Running object detection inference over page page_147.png.
# Running object detection inference over page page_148.png.
# Running object detection inference over page page_149.png.
# Running object detection inference over page page_15.png.
# Running object detection inference over page page_150.png.
# Running object detection inference over page page_151.png.
# Running object detection inference over page page_152.png.
# Running object detection inference over page page_153.png.
# Running object detection inference over page page_154.png.
# Running object detection inference over page page_155.png.
# Running object detection inference over page page_156.png.
# Running object detection inference over page page_157.png.
# Running object detection inference over page page_158.png.
# Running object detection inference over page page_159.png.
# Running object detection inference over page page_16.png.
# Running object detection inference over page page_160.png.
# Running object detection inference over page page_161.png.
# Running object detection inference over page page_162.png.
# Running object detection inference over page page_163.png.
# Running object detection inference over page page_164.png.
# Running object detection inference over page page_165.png.
# Running object detection inference over page page_166.png.
# Running object detection inference over page page_167.png.
# Running object detection inference over page page_168.png.
# Running object detection inference over page page_169.png.
# Running object detection inference over page page_17.png.
# Running object detection inference over page page_170.png.
# Running object detection inference over page page_171.png.
# Running object detection inference over page page_172.png.
# Running object detection inference over page page_173.png.
# Running object detection inference over page page_174.png.
# Running object detection inference over page page_175.png.
# Running object detection inference over page page_176.png.
# Running object detection inference over page page_177.png.
# Running object detection inference over page page_178.png.
# Running object detection inference over page page_179.png.
# Running object detection inference over page page_18.png.
# Running object detection inference over page page_180.png.
# Running object detection inference over page page_19.png.
# Running object detection inference over page page_2.png.
# Running object detection inference over page page_20.png.
# Running object detection inference over page page_21.png.
# Running object detection inference over page page_22.png.
# Running object detection inference over page page_23.png.
# Running object detection inference over page page_24.png.
# Running object detection inference over page page_25.png.
# Running object detection inference over page page_26.png.
# Running object detection inference over page page_27.png.
# Running object detection inference over page page_28.png.
# Running object detection inference over page page_29.png.
# Running object detection inference over page page_3.png.
# Running object detection inference over page page_30.png.
# Running object detection inference over page page_31.png.
# Running object detection inference over page page_32.png.
# Running object detection inference over page page_33.png.
# Running object detection inference over page page_34.png.
# Running object detection inference over page page_35.png.
# Running object detection inference over page page_36.png.
# Running object detection inference over page page_37.png.
# Running object detection inference over page page_38.png.
# Running object detection inference over page page_39.png.
# Running object detection inference over page page_4.png.
# Running object detection inference over page page_40.png.
# Running object detection inference over page page_41.png.
# Running object detection inference over page page_42.png.
# Running object detection inference over page page_43.png.
# Running object detection inference over page page_44.png.
# Running object detection inference over page page_45.png.
# Running object detection inference over page page_46.png.
# Running object detection inference over page page_47.png.
# Running object detection inference over page page_48.png.
# Running object detection inference over page page_49.png.
# Running object detection inference over page page_5.png.
# Running object detection inference over page page_50.png.
# Running object detection inference over page page_51.png.
# Running object detection inference over page page_52.png.
# Running object detection inference over page page_53.png.
# Running object detection inference over page page_54.png.
# Running object detection inference over page page_55.png.
# Running object detection inference over page page_56.png.
# Running object detection inference over page page_57.png.
# Running object detection inference over page page_58.png.
# Running object detection inference over page page_59.png.
# Running object detection inference over page page_6.png.
# Running object detection inference over page page_60.png.
# Running object detection inference over page page_61.png.
# Running object detection inference over page page_62.png.
# Running object detection inference over page page_63.png.
# Running object detection inference over page page_64.png.
# Running object detection inference over page page_65.png.
# Running object detection inference over page page_66.png.
# Running object detection inference over page page_67.png.
# Running object detection inference over page page_68.png.
# Running object detection inference over page page_69.png.
# Running object detection inference over page page_7.png.
# Running object detection inference over page page_70.png.
# Running object detection inference over page page_71.png.
# Running object detection inference over page page_72.png.
# Running object detection inference over page page_73.png.
# Running object detection inference over page page_74.png.
# Running object detection inference over page page_75.png.
# Running object detection inference over page page_76.png.
# Running object detection inference over page page_77.png.
# Running object detection inference over page page_78.png.
# Running object detection inference over page page_79.png.
# Running object detection inference over page page_8.png.
# Running object detection inference over page page_80.png.
# Running object detection inference over page page_81.png.
# Running object detection inference over page page_82.png.
# Running object detection inference over page page_83.png.
# Running object detection inference over page page_84.png.
# Running object detection inference over page page_85.png.
# Running object detection inference over page page_86.png.
# Running object detection inference over page page_87.png.
# Running object detection inference over page page_88.png.
# Running object detection inference over page page_89.png.
# Running object detection inference over page page_9.png.
# Running object detection inference over page page_90.png.
# Running object detection inference over page page_91.png.
# Running object detection inference over page page_92.png.
# Running object detection inference over page page_93.png.
# Running object detection inference over page page_94.png.
# Running object detection inference over page page_95.png.
# Running object detection inference over page page_96.png.
# Running object detection inference over page page_97.png.
# Running object detection inference over page page_98.png.
# Running object detection inference over page page_99.png.
